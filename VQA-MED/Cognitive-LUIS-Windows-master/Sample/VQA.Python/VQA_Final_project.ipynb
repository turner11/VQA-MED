# %% [markdown]
# # VQA - MED

# %% [markdown]
# This notebook demostraits the efforts made for Visual Q&A based on the data set from VQA-Med 2018 contest

# %% [markdown]
# ## Abstract

# %% [markdown]
# The inputs for VQA are:
# 1. The question text
# 2. The image
#
# The question text is being embedded into a feature vector using a pre-traing [globe file](https://nlp.stanford.edu/projects/glove/).
#
# In a similar manner the image is being processed using a pre trained deep NN (e.g. [VGG](http://qr.ae/TUTEKo) with initial wights of a pretrained [imagenet model](https://en.wikipedia.org/wiki/ImageNet))

# %% [markdown]
# ## The plan

# %% [markdown]
# 0. [Preperations and helpers](#Preperations-and-helpers)
# 1. [Collecting pre processing item](#Collecting-pre-processing-item)
# 2. [Preprocessing and creating meta data](#Preprocessing-and-creating-meta-data)
# 3. [Creating the model](#Creating-the-model)
# 4. [Training the model](#Training-the-model)
# 5. [Testing the model](#Testing-the-model)

# %% [markdown]
# ### Preperations and helpers

# %% [markdown]
# The following are just helpers & utils imports - feel free to skip...

# %%
from parsers.utils import VerboseTimer
from utils.os_utils import File, print_progress
import time, datetime

def get_time_stamp():
    now = time.time()
    ts = datetime.datetime.fromtimestamp(now).strftime('%Y%m%d_%H%M_%S')
    return ts

# %% [markdown]
# ### Collecting pre processing item

# %% [markdown]
# ###### Download pre trained items & store their location

# %%
#TODO: Add down loading for glove file

# %%
import os
seq_length =    26
embedding_dim = 300

glove_path =                    os.path.abspath('data/glove.6B.{0}d.txt'.format(embedding_dim))
embedding_matrix_filename =     os.path.abspath('data/ckpts/embeddings_{0}.h5'.format(embedding_dim))
ckpt_model_weights_filename =   os.path.abspath('data/ckpts/model_weights.h5')




DEFAULT_IMAGE_WIEGHTS = 'imagenet'
#  Since VGG was trained as a image of 224x224, every new image
# is required to go through the same transformation
image_size_by_base_models = {'imagenet': (224, 224)}

# %%
import os
# Fail fast...
suffix = "Failing fast:\n"
assert os.path.isfile(glove_path), suffix+"glove file does not exists:\n{0}".format(glove_path)
# assert os.path.isfile(embedding_matrix_filename), suffix+"Embedding matrix file does not exist:\n{0}".format(embedding_matrix_filename)
assert os.path.isfile(ckpt_model_weights_filename), suffix+"glove file does not exists:\n{0}".format(ckpt_model_weights_filename)

print('Validated file locations')
# Out:
# Validated file locations

# %% [markdown]
# ##### Set locations for pre-training items to-be created

# %%
# Pre process results files
data_prepo_meta            = os.path.abspath('data/my_data_prepro.json')
data_prepo_meta_validation = os.path.abspath('data/my_data_prepro_validation.json')
# Location of embediing pre trained matrix
embedding_matrix_filename  = os.path.abspath('data/ckpts/embeddings_{0}.h5'.format(embedding_dim))

# The location to dump models to
vqa_models_folder          = "C:\\Users\\Public\\Documents\\Data\\2018\\vqa_models"

# %% [markdown]
# ### Preprocessing and creating meta data

# %% [markdown]
# We will use this function for creating meta data:

# %%
from vqa_logger import logger 
import itertools
import string
from utils.os_utils import File #This is a simplehelper file of mine...

def create_meta(meta_file_location, df):
        logger.debug("Creating meta data ('{0}')".format(meta_file_location))
        def get_unique_words(col):
            single_string = " ".join(df[col])
            exclude = set(string.punctuation)
            s_no_panctuation = ''.join(ch for ch in single_string if ch not in exclude)
            unique_words = set(s_no_panctuation.split(" ")).difference({'',' '})
            print("column {0} had {1} unique words".format(col,len(unique_words)))
            return unique_words

        cols = ['question', 'answer']
        unique_words = set(itertools.chain.from_iterable([get_unique_words(col) for col in cols]))
        print("total unique words: {0}".format(len(unique_words)))

        metadata = {}
        metadata['ix_to_word'] = {str(word): int(i) for i, word in enumerate(unique_words)}
        metadata['ix_to_ans'] = {ans:i for ans, i in enumerate(set(df['answer']))}
        # {int(i):str(word) for i, word in enumerate(unique_words)}

        File.dump_json(metadata,meta_file_location)
        return metadata

# %% [markdown]
# And lets create meta data for training & validation sets:

# %%
from collections import namedtuple
dbg_file_csv_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA.csv'
dbg_file_xls_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA_post_pre_process_intermediate.xlsx'#"'C:\\\\Users\\\\avitu\\\\Documents\\\\GitHub\\\\VQA-MED\\\\VQA-MED\\\\Cognitive-LUIS-Windows-master\\\\Sample\\\\VQA.Python\\\\dumped_data\\\\vqa_data.xlsx'
dbg_file_xls_processed_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA_post_pre_process.xlsx'
train_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-images\\embbeded_images.hdf'
images_path_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-images'


dbg_file_csv_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA.csv'
dbg_file_xls_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA_post_pre_process_intermediate.xlsx'
dbg_file_xls_processed_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA_post_pre_process.xlsx'
validation_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-images\\embbeded_images.hdf'
images_path_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-images'


dbg_file_csv_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA.csv'
dbg_file_xls_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA_post_pre_process_intermediate.xlsx'
dbg_file_xls_processed_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA_post_pre_process.xlsx'
test_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-images\\embbeded_images.hdf'
images_path_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-images'

DataLocations = namedtuple('DataLocations', ['data_tag', 'raw_csv', 'raw_xls', 'processed_xls','images_path'])
train_data = DataLocations('train', dbg_file_csv_train,dbg_file_xls_train,dbg_file_xls_processed_train, images_path_train)
validation_data = DataLocations('validation', dbg_file_csv_validation, dbg_file_xls_validation, dbg_file_xls_processed_validation, images_path_validation)
test_data = DataLocations('test', dbg_file_csv_test, dbg_file_xls_test, dbg_file_xls_processed_test, images_path_test)

# %% [markdown]
# Get the data itself, Note the only things required in dataframe are:
# 1. image_name
# 2. question
# 3. answer

# %%
from parsers.VQA18 import Vqa18Base
df_train = Vqa18Base.get_instance(train_data.processed_xls).data            
df_val = Vqa18Base.get_instance(validation_data.processed_xls).data
df_train.head(2)
# Out:
# 20:48:25,934 matplotlib DEBUG ## $HOME=C:\Users\avitu
# 20:48:25,935 matplotlib DEBUG ## matplotlib data path c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\matplotlib\mpl-data
# 20:48:25,941 matplotlib DEBUG ## loaded rc file c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 20:48:25,944 matplotlib DEBUG ## matplotlib version 2.2.2
# 20:48:25,945 matplotlib DEBUG ## interactive is False
# 20:48:25,946 matplotlib DEBUG ## platform is win32
# 20:48:25,947 matplotlib DEBUG ## loaded modules: ['builtins', 'sys', '_frozen_importlib', '_imp', '_warnings', '_thread', '_weakref', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'zipimport', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_weakrefset', '_bootlocale', '_locale', 'encodings.cp1255', 'site', 'os', 'errno', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'sysconfig', 'types', 'functools', '_functools', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'weakref', 'collections.abc', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'mpl_toolkits', 'google', 'runpy', 'pkgutil', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'ast', '_ast', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'textwrap', 'gettext', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.openpy', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.signatures', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputsplitter', 'IPython.core.inputtransformer', 'IPython ...
#     mri  brain                      answer  hematoma   neck  liver  \
# 0  True  False  lesion at tail of pancreas     False  False  False
# 1  True  False          in distal pancreas     False  False  False
#
#                                   tokenized_question     ct  abdomen  row_id  \
# 0                                what doe MRI show ?  False    False       1
# 1  where doe axial seCTion MRI abdomen show hypoe...  False     True       2
#
#          image_name  tumor                                           question  \
# 0          rjv03401   True                                what does mri show?
# 1  AIAN-14-313-g002  False  where does axial section mri abdomen show hypo...
#
#          tokenized_answer
# 0  tumor at tail pancreas
# 1         distal pancreas

# %%
print("----- Creating training meta -----")
meta_train = create_meta(data_prepo_meta, df_train)

print("\n----- Creating validation meta -----")
meta_validation = create_meta(data_prepo_meta, df_val)

meta_train
# Out:
# 20:48:26,955 pythonVQA DEBUG ## Creating meta data ('C:\Users\avitu\Documents\GitHub\VQA-MED\VQA-MED\Cognitive-LUIS-Windows-master\Sample\VQA.Python\data\my_data_prepro.json')
# 20:48:27,70 pythonVQA DEBUG ## Creating meta data ('C:\Users\avitu\Documents\GitHub\VQA-MED\VQA-MED\Cognitive-LUIS-Windows-master\Sample\VQA.Python\data\my_data_prepro.json')
# ----- Creating training meta -----
# column question had 3317 unique words
# column answer had 3255 unique words
# total unique words: 3578
#
# ----- Creating validation meta -----
# column question had 399 unique words
# column answer had 669 unique words
# total unique words: 881
# {'ix_to_word': {'alcyceal': 0,
#   'spinal': 1,
#   'swelling': 2,
#   'mapping': 3,
#   'outflow': 4,
#   'favorable': 5,
#   'lead': 6,
#   'hydroureter': 7,
#   'horseshoe': 8,
#   'misplaced': 9,
#   'V': 10,
#   'interposition': 11,
#   'portography': 12,
#   'atlantooccipital': 13,
#   'reduced': 14,
#   'nerve': 15,
#   'ileocolic': 16,
#   'ileoanal': 17,
#   'multifidus': 18,
#   'giant': 19,
#   'bud': 20,
#   'flat': 21,
#   'spair': 22,
#   'Reaccumulation': 23,
#   '10': 24,
#   'operative': 25,
#   'evisceration': 26,
#   'interpole': 27,
#   'based': 28,
#   'occlusion': 29,
#   'demarcated': 30,
#   'nonocclusive': 31,
#   'contents': 32,
#   'day': 33,
#   'reduction': 34,
#   'collections': 35,
#   'severe': 36,
#   'layering': 37,
#   'septations': 38,
#   'peripheral': 39,
#   'translocation': 40,
#   'ascites': 41,
#   'xmr': 42,
#   'placental': 43,
#   'radiodense': 44,
#   'groin': 45,
#   'csf': 46,
#   'glioblastome': 47,
#   'lid': 48,
#   'neurography': 49,
#   'subsequent': 50,
#   'slowly': 51,
#   'femur': 52,
#   'zone': 53,
#   'T1WI': 54,
#   'sagital': 55,
#   'curved': 56,
#   'communication': 57,
#   'values': 58,
#   'posttreatment': 59,
#   'agent': 60,
#   'nodal': 61,
#   'chiasm': 62,
#   'bulb': 63,
#   'processed': 64,
#   'collection': 65,
#   'shoulder': 66,
#   'walker': 67,
#   'skin': 68,
#   'nucleus': 69,
#   'ramus': 70,
#   'legion': 71,
#   'encapsulated': 72,
#   'intraocular': 73,
#   'mostly': 74,
#   'entrance': 75,
#   'intraosseous': 76,
#   'carotid': 77,
#   'anteverted': 78,
#   'great': 79,
#   'substitution': 80,
#   'filling': 81,
#   'sized': 82,
#   'cystoid': 83,
#   'how': 84,
#   'cecum': 85,
#   'this': 86,
#   'cruciate': 87,
#   't10': 88,
#   'beneath': 89,
#   'genal': 90,
#   'ultra': 91,
#   'beside': 92,
#   'typical': 93,
#   '30': 94,
#   'presence': 95,
#   'weighted': 96,
#   'Intracranial': 97,
#   'dental': 98,
#   'blush': 99,
#   'object': 100,
#   'endobronchial': 101,
#   'responsible': 102,
#   'pneumobilia': 103,
#   'renal': 104,
#   'gd': 105,
#   'Enhancing': 106,
#   'gradient': 107,
#   'malposition': 108,
#   'formation': 109,
#   'leading': 110,
#   'glass': 111,
#   'peritoneum': 112,
#   'severely': 113,
#   'walls': 114,
#   'afferent': 115,
#   'paracardiac': 116,
#   'pressing': 117,
#   'parasagittal': 118,
#   'spleen': 119,
#   'technique': 120,
#   'superior': 121,
#   'remaining': 122,
#   'sternocleidomastoid': 123,
#   'circular': 124,
#   'segments': 125,
#   'bronchomegaly': 126,
#   'hemangioma': 127,
#   'calyceal': 128,
#   'haemangioma': 129,
#   'callosum': 130,
#   'grow': 131,
#   'facetal': 132,
#   'osseous': 133,
#   'region': 134,
#   'bifurcation': 135,
#   'diskspace': 136,
#   'postcontrast': 137,
#   'medially': 138,
#   'ground': 139,
#   'transfer': 140,
#   'c7': 141,
#   'pharyngeal': 142,
#   'penis': 143,
#   'triphasic': 144,
#   'temporalis': 145,
#   'hypothalamo': 146,
#   'compression': 147,
#   'falx': 148,
#   'benign': 149,
#   'definite': 150,
#   'stenotic': 151,
#   'ECRL': 152,
#   'flushing': 153,
#   'neoplasm': 154,
#   'gadoliniumcontrast': 155,
#   'pericardial': 156,
#   'fetus': 157,
#   'biloma': 158,
#   'culmen': 159,
#   'decreased': 160,
#   'C4': 161,
#   'sacroiliac': 162,
#   'fixation': 163,
#   'incomplete': 164,
#   'expanding': 165,
#   'intestines': 166,
#   'abdominopelvic': 167,
#   'mosaic': 168,
#   'terminal': 169,
#   'fragmentation': 170,
#   'tubular': 171,
#   'sac': 172,
#   'neuritis': 173,
#   'protruded': 174,
#   'MM': 175,
#   'lies': 176,
#   'develops': 177,
#   'diffuse': 178,
#   'lumbosacral': 179,
#   'modified': 180,
#   'only': 181,
#   'Suspicion': 182,
#   'delineation': 183,
#   'Abd': 184,
#   'utero': 185,
#   'surveillance': 186,
#   'subtle': 187,
#   'simultaneous': 188,
#   'headache': 189,
#   'aspect': 190,
#   'hid': 191,
#   'pneumoperitoneum': 192,
#   'segmentation': 193,
#   'schwannomas': 194,
#   'damaged': 195,
#   'separated': 196,
#   '34mm': 197,
#   'luno': 198,
#   'obstructive': 199,
#   'alternate': 200,
#   'pleural': 201,
#   'svc': 202,
#   'almost': 203,
#   'wide': 204,
#   'ls': 205,
#   'scolex': 206,
#   'supratentorium': 207,
#   'osteoarthritis': 208,
#   'her': 209,
#   'reaching': 210,
#   'transition': 211,
#   'pubic': 212,
#   'buccal': 213,
#   'extensions': 214,
#   'draining': 215,
#   'occipito': 216,
#   'aortic': 217,
#   'sacro': 218,
#   'olecranon': 219,
#   'broad': 220,
#   'ct': 221,
#   'transethmoidal': 222,
#   'bile': 223,
#   'chemoradiation': 224,
#   'processus': 225,
#   'illustrates': 226,
#   'poor': 227,
#   'pneumoscrotum': 228,
#   'discussed': 229,
#   'clefting': 230,
#   'vesicles': 231,
#   'cortex': 232,
#   'Brain': 233,
#   'dose': 234,
#   'larynx': 235,
#   'FLAIR': 236,
#   'periventricular': 237,
#   'parastomal': 238,
#   'folia': 239,
#   'spanning': 240,
#   'artefact': 241,
#   'widespread': 242,
#   'hypo': 243,
#   'pylorus': 244,
#   'synchondroses': 245,
#   'bronchi': 246,
#   'myocardial': 247,
#   'lamellar': 248,
#   'clinically': 249,
#   'pneumorrhachis': 250,
#   'pars': 251,
#   'coffee': 252,
#   'prior': 253,
#   'abscess': 254,
#   'asdh': 255,
#   'psudomeningocele': 256,
#   'condyle': 257,
#   'pushing': 258,
#   'D11': 259,
#   'disclose': 260,
#   'parts': 261,
#   'hypoechoic': 262,
#   'planes': 263,
#   'incisional': 264,
#   'avn': 265,
#   'especially': 266,
#   'sinus': 267,
#   'There': 268,
#   'mural': 269,
#   'largest': 270,
#   'rendered': 271,
#   'cancer': 272,
#   'Kellgren': 273,
#   '50': 274,
#   'ureterovaginal': 275,
#   'foreign': 276,
#   'veins': 277,
#   'woman': 278,
#   'cervical': 279,
#   'ilium': 280,
#   'outer': 281,
#   'explicit': 282,
#   'mucositis': 283,
#   'kommerells': 284,
#   'pterygoids': 285,
#   'floor': 286,
#   'subcutaneously': 287,
#   'Post': 288,
#   'devils': 289,
#   'encephalopathy': 290,
#   'bmc': 291,
#   'locule': 292,
#   'centro': 293,
#   'concurrent': 294,
#   'C3': 295,
#   'laceration': 296,
#   'nuck': 297,
#   'first': 298,
#   'ssfp': 299,
#   'tracts': 300,
#   'roundlike': 301,
#   'avid': 302,
#   'sulcal': 303,
#   'pheochromacytoma': 304,
#   'humeral': 305,
#   'proved': 306,
#   'perigastric': 307,
#   'subthalamic': 308,
#   'confluent': 309,
#   'proctocolectomy': 310,
#   'needle': 311,
#   'moderate': 312,
#   'maxillary': 313,
#   'uninvolved': 314,
#   'guided': 315,
#   'myelocystocele': 316,
#   'ACL': 317,
#   'withan': 318,
#   'failing': 319,
#   'border': 320,
#   'tiger': 321,
#   'open': 322,
#   'subocclusive': 323,
#   'dehiscence': 324,
#   'clitoris': 325,
#   'spread': 326,
#   'dripping': 327,
#   'intruding': 328,
#   'weight': 329,
#   'scout': 330,
#   'backfilling': 331,
#   'suprapubic': 332,
#   'cisternography': 333,
#   'completely': 334,
#   'plate': 335,
#   'extremities': 336,
#   'aphasia': 337,
#   'clearly': 338,
#   'product': 339,
#   'vena': 340,
#   'usual': 341,
#   'metopic': 342,
#   'detachment': 343,
#   'seen': 344,
#   'calculi': 345,
#   'peribronchovascular': 346,
#   'mineralization': 347,
#   'Postembolization': 348,
#   'perisigmoid': 349,
#   'partially': 350,
#   'intraperitoneal': 351,
#   'candle': 352,
#   'bladders': 353,
#   'highly': 354,
#   'considered': 355,
#   'lata': 356,
#   'bleeding': 357,
#   'sarcoma': 358,
#   'cervix': 359,
#   'huge': 360,
#   'settings': 361,
#   '31': 362,
#   'opened': 363,
#   'originating': 364,
#   'hematometra': 365,
#   'kind': 366,
#   'fibrocystic': 367,
#   'biliary': 368,
#   'bifrontalbitemporal': 369,
#   'trochleaplasty': 370,
#   'tenosynovitis': 371,
#   'C6': 372,
#   'obscure': 373,
#   'peduncles': 374,
#   'inferio': 375,
#   'regimen': 376,
#   'track': 377,
#   'sulfate': 378,
#   'infant': 379,
#   'impaction': 380,
#   'with': 381,
#   'cupula': 382,
#   'venography': 383,
#   'moiety': 384,
#   'limits': 385,
#   'leiomyoma': 386,
#   'opaque': 387,
#   'lie': 388,
#   'thalamic': 389,
#   'effect': 390,
#   'venous': 391,
#   'connector': 392,
#   'excretion': 393,
#   'occulta': 394,
#   'malignant': 395,
#   'possibility': 396,
#   'gadolinium': 397,
#   'nonunion': 398,
#   'carcinoid': 399,
#   'milk': 400,
#   'malignancy': 401,
#   'indenting': 402,
#   'hypoplastic': 403,
#   'subscapularis': 404,
#   'lytic': 405,
#   'discontinuity': 406,
#   'vertebra': 407,
#   'hyperdensity': 408,
#   'numerous': 409,
#   'lesional': 410,
#   'malformations': 411,
#   'dot': 412,
#   'there': 413,
#   'rhombus': 414,
#   'masticator': 415,
#   'intracerebral': 416,
#   'centrally': 417,
#   'apposition': 418,
#   'second': 419,
#   'coeliomesenteric': 420,
#   'tubercular': 421,
#   'parasaggital': 422,
#   'transitional': 423,
#   'hemithorax': 424,
#   'dura': 425,
#   'ulcerative': 426,
#   'thick': 427,
#   'endplate': 428,
#   'these': 429,
#   'spondylitis': 430,
#   'hemicolectomy': 431,
#   'disconnection': 432,
#   'year': 433,
#   'relapse': 434,
#   'insula': 435,
#   '3dct': 436,
#   'chunks': 437,
#   'barium': 438,
#   'solitary': 439,
#   'immediate': 440,
#   'bronchial': 441,
#   'lymphoma': 442,
#   'polyhydramnios': 443,
#   'signs': 444,
#   'recurrence': 445,
#   'enlarged': 446,
#   'thalamo': 447,
#   'osteopetrosis': 448,
#   'cirrhotic': 449,
#   'intrapulmonary': 450,
#   'via': 451,
#   'by': 452,
#   'around': 453,
#   'centralis': 454,
#   'fascicular': 455,
#   'snapshot': 456,
#   'pericardium': 457,
#   'dissecting': 458,
#   'colpocephaly': 459,
#   'cect': 460,
#   'vegetating': 461,
#   'tumorous': 462,
#   'subject': 463,
#   'intraspinal': 464,
#   'aqueduct': 465,
#   'straightening': 466,
#   'improved': 467,
#   'tumors': 468,
#   'improvement': 469,
#   'socket': 470,
#   'markings': 471,
#   'fields': 472,
#   'duodenum': 473,
#   'cerebellar': 474,
#   'massive': 475,
#   'thoracolumbar': 476,
#   'free': 477,
#   'lamina': 478,
#   'iso': 479,
#   'rul': 480,
#   'Retroperitoneal': 481,
#   'medulla': 482,
#   'epidural': 483,
#   'vascularity': 484,
#   'significant': 485,
#   'placed': 486,
#   'fb': 487,
#   'obstructing': 488,
#   'surasellar': 489,
#   'when': 490,
#   'compared': 491,
#   'dota': 492,
#   'final': 493,
#   'dural': 494,
#   'below': 495,
#   'foramen': 496,
#   'alar': 497,
#   'including': 498,
#   'L1': 499,
#   'Two': 500,
#   'sites': 501,
#   'fibrofatty': 502,
#   'discloses': 503,
#   'thickwalled': 504,
#   'pollicis': 505,
#   'evidence': 506,
#   'prominence': 507,
#   'sides': 508,
#   'neurofibroma': 509,
#   'sternoclavicular': 510,
#   'syringomyelia': 511,
#   'acl': 512,
#   'disk': 513,
#   'tension': 514,
#   'coccyx': 515,
#   'duplicated': 516,
#   'attenuation': 517,
#   'chest': 518,
#   'containing': 519,
#   'instead': 520,
#   'cvj': 521,
#   'supraglottic': 522,
#   'the': 523,
#   'vitreous': 524,
#   'pectoralis': 525,
#   'structures': 526,
#   'muscular': 527,
#   'intrathoracic': 528,
#   'slide': 529,
#   'sided': 530,
#   'anatomic': 531,
#   't1': 532,
#   'fess': 533,
#   'muscle': 534,
#   'pericaecal': 535,
#   'tube': 536,
#   'ophthalmic': 537,
#   'resolved': 538,
#   'anorectal': 539,
#   'palatinal': 540,
#   'indentation': 541,
#   'inhomogeneous': 542,
#   'display': 543,
#   'time': 544,
#   'bilateral': 545,
#   'macro': 546,
#   'cavitation': 547,
#   'bullet': 548,
#   'bridging': 549,
#   'pure': 550,
#   'obtuse': 551,
#   'prostate': 552,
#   'acetabulum': 553,
#   'circulation': 554,
#   'thymus': 555,
#   'peribronchial': 556,
#   'stable': 557,
#   'cardiophrenic': 558,
#   'arachnoid': 559,
#   'cloaca': 560,
#   'mobi': 561,
#   'green': 562,
#   'canals': 563,
#   'aryepiglottic': 564,
#   'line': 565,
#   'medius': 566,
#   'rectum': 567,
#   'radiofrequency': 568,
#   'relapsed': 569,
#   'infiltration': 570,
#   'serosal': 571,
#   'erosions': 572,
#   'infarction': 573,
#   'transverse': 574,
#   'suggest': 575,
#   'variceal': 576,
#   'trachea': 577,
#   'probably': 578,
#   'cranioplasty': 579,
#   'heterotopia': 580,
#   'Coronary': 581,
#   'Right': 582,
#   'no': 583,
#   'prominent': 584,
#   'base': 585,
#   'atlantoaxial': 586,
#   'units': 587,
#   'subluxation': 588,
#   'vasogenic': 589,
#   'inner': 590,
#   'became': 591,
#   '70': 592,
#   'voltage': 593,
#   'width': 594,
#   'nut': 595,
#   'Triventricular': 596,
#   'bodies': 597,
#   'ureter': 598,
#   'communicating': 599,
#   'leg': 600,
#   'sinonasal': 601,
#   'demonstrated': 602,
#   'perilesional': 603,
#   'starry': 604,
#   'ionic': 605,
#   'iliac': 606,
#   'internal': 607,
#   'thigh': 608,
#   'but': 609,
#   'several': 610,
#   'taken': 611,
#   'displaced': 612,
#   'healthy': 613,
#   'lad': 614,
#   'infectious': 615,
#   'agenetic': 616,
#   'systems': 617,
#   'papery': 618,
#   'couch': 619,
#   'segment': 620,
#   'c4': 621,
#   '3d': 622,
#   'sequence': 623,
#   'generalized': 624,
#   'ileum': 625,
#   'compound': 626,
#   'seemingly': 627,
#   'involve': 628,
#   'rotator': 629,
#   'divertion': 630,
#   'band': 631,
#   'orbits': 632,
#   'ect': 633,
#   'post': 634,
#   'flank': 635,
#   'trabecular': 636,
#   'multiloculated': 637,
#   'zygomatic': 638,
#   'remained': 639,
#   'perforation': 640,
#   'subligamentous': 641,
#   'interarticularis': 642,
#   'intrasubstance': 643,
#   'views': 644,
#   'polychorous': 645,
#   'diminished': 646,
#   'choroid': 647,
#   'tumorfree': 648,
#   'minimal': 649,
#   'slightly': 650,
#   'pseudocyst': 651,
#   'visualizability': 652,
#   'predominantly': 653,
#   'ligament': 654,
#   'tendo': 655,
#   'coil': 656,
#   'source': 657,
#   'haemoperitoneum': 658,
#   'd11': 659,
#   'vein': 660,
#   'temporomandibular': 661,
#   'calculus': 662,
#   'beyond': 663,
#   'metaphyseal': 664,
#   'subfalcine': 665,
#   'cavernosa': 666,
#   'visual': 667,
#   'meninges': 668,
#   'indicating': 669,
#   'marsupialization': 670,
#   'fraction': 671,
#   'vermis': 672,
#   'rv': 673,
#   'hyperdense': 674,
#   'periphery': 675,
#   'lunotriquetral': 676,
#   'cranio': 677,
#   '5th': 678,
#   'dorsolumbar': 679,
#   'developing': 680,
#   'caused': 681,
#   'presented': 682,
#   'hypersignality': 683,
#   'olfactory': 684,
#   'space': 685,
#   'starfield': 686,
#   'inframammary': 687,
#   'darkblood': 688,
#   'micronodules': 689,
#   'defects': 690,
#   'vastus': 691,
#   'cerebrum': 692,
#   'athletic': 693,
#   'setting': 694,
#   'alignment': 695,
#   'sign': 696,
#   'compressing': 697,
#   'metal': 698,
#   'corresponding': 699,
#   'relatively': 700,
#   'TL1': 701,
#   'foley': 702,
#   'most': 703,
#   '64': 704,
#   'homogeneously': 705,
#   'incarceration': 706,
#   'hydroureteronephrosis': 707,
#   'tridimensional': 708,
#   'popliteal': 709,
#   'generalised': 710,
#   'touch': 711,
#   'midgut': 712,
#   'glioma': 713,
#   'sparing': 714,
#   'subclavian': 715,
#   'layer': 716,
#   'midline': 717,
#   'using': 718,
#   'his': 719,
#   'to': 720,
#   'expansive': 721,
#   'lying': 722,
#   'knee': 723,
#   'membranes': 724,
#   'angioma': 725,
#   'drainage': 726,
#   'nodular': 727,
#   'arthrosis': 728,
#   'distension': 729,
#   'characteristic': 730,
#   'hill': 731,
#   'ankylosed': 732,
#   'finger': 733,
#   'intracranial': 734,
#   'folds': 735,
#   'pedicle': 736,
#   'contraceptive': 737,
#   'coracoglenoid': 738,
#   'nonenhanced': 739,
#   'intercostal': 740,
#   'sphincter': 741,
#   'limited': 742,
#   'neurobeh': 743,
#   'months': 744,
#   'ossicular': 745,
#   'parietooccipital': 746,
#   'vivo': 747,
#   'occupying': 748,
#   'flakes': 749,
#   'tricuspid': 750,
#   'procedure': 751,
#   'scar': 752,
#   'contralateral': 753,
#   'descending': 754,
#   'lining': 755,
#   'without': 756,
#   'parietotemporal': 757,
#   'fmd': 758,
#   'compressed': 759,
#   'many': 760,
#   'displays': 761,
#   'nocardia': 762,
#   'visualization': 763,
#   'cholecysto': 764,
#   'horse': 765,
#   'homogeneous': 766,
#   'concha': 767,
#   'lactate': 768,
#   'activity': 769,
#   'epicondyle': 770,
#   'ventricles': 771,
#   'aneurysmal': 772,
#   'scapula': 773,
#   'cone': 774,
#   'cv': 775,
#   'plasmacytoma': 776,
#   'intraarticular': 777,
#   'crescentshaped': 778,
#   'lungs': 779,
#   'Thick': 780,
#   'localizations': 781,
#   'collapsed': 782,
#   'watershed': 783,
#   'infarcted': 784,
#   'pulp': 785,
#   'crazy': 786,
#   'tail': 787,
#   'subcapsular': 788,
#   'rim': 789,
#   'hepatis': 790,
#   'l5': 791,
#   'against': 792,
#   'leaking': 793,
#   'set': 794,
#   'Multiple': 795,
#   'deficient': 796,
#   'retroperitoneal': 797,
#   'anomalous': 798,
#   'look': 799,
#   'locations': 800,
#   'our': 801,
#   'bevacizumab': 802,
#   'Ophthalmopathy': 803,
#   'preservation': 804,
#   'occupied': 805,
#   'putaminal': 806,
#   'spiral': 807,
#   'subhepatic': 808,
#   'reconstructions': 809,
#   'layered': 810,
#   'ambiguous': 811,
#   'seal': 812,
#   'central': 813,
#   'nodule': 814,
#   'signifiant': 815,
#   'and': 816,
#   'defect': 817,
#   'midface': 818,
#   'papilla': 819,
#   'cns': 820,
#   'paranasal': 821,
#   'CT': 822,
#   'neoplastic': 823,
#   'fingerlike': 824,
#   'extraaxial': 825,
#   'dislocation': 826,
#   'septated': 827,
#   'sellae': 828,
#   'stones': 829,
#   'fascial': 830,
#   'enteroclysis': 831,
#   'anastomotic': 832,
#   'obvious': 833,
#   'papillary': 834,
#   'of': 835,
#   'pore': 836,
#   'delineated': 837,
#   'anophthalmia': 838,
#   'extraspinal': 839,
#   'bowelinbowel': 840,
#   'sacular': 841,
#   'passage': 842,
#   'Oblique': 843,
#   'hypertrophic': 844,
#   'ap': 845,
#   'edge': 846,
#   'wound': 847,
#   'parieto': 848,
#   'cranium': 849,
#   'naked': 850,
#   'oesophagus': 851,
#   'revealed': 852,
#   'it': 853,
#   'palmar': 854,
#   'osteoblastic': 855,
#   'face': 856,
#   'divisum': 857,
#   'way': 858,
#   'synovial': 859,
#   'rads': 860,
#   '2': 861,
#   'appear': 862,
#   'nipple': 863,
#   'deviation': 864,
#   'ossicle': 865,
#   'ringenhancing': 866,
#   'spt': 867,
#   'Computed': 868,
#   'infiltrated': 869,
#   'oropharyngeal': 870,
#   'atlas': 871,
#   'uptake': 872,
#   'facial': 873,
#   'again': 874,
#   'leptomeningeal': 875,
#   'Large': 876,
#   'lung': 877,
#   'apex': 878,
#   '13': 879,
#   'components': 880,
#   'spect': 881,
#   'polycyclic': 882,
#   'canine': 883,
#   'proliferation': 884,
#   'capsule': 885,
#   'IV': 886,
#   'photograph': 887,
#   'gluteus': 888,
#   'ankle': 889,
#   'isolated': 890,
#   'multifoci': 891,
#   'c3': 892,
#   'traumatic': 893,
#   'postsecond': 894,
#   'bullosa': 895,
#   'removed': 896,
#   'dorsi': 897,
#   'nasopharyngeal': 898,
#   'acalculous': 899,
#   'intraventricular': 900,
#   'end': 901,
#   'that': 902,
#   'areas': 903,
#   'temporal': 904,
#   'presentation': 905,
#   'interlobular': 906,
#   'collapse': 907,
#   'vrt': 908,
#   'ear': 909,
#   '29th': 910,
#   'posteromedial': 911,
#   'intussusception': 912,
#   'Scattered': 913,
#   'replacing': 914,
#   'placode': 915,
#   'course': 916,
#   'welldefined': 917,
#   'perfusion': 918,
#   'extensor': 919,
#   'clearance': 920,
#   'marker': 921,
#   'patent': 922,
#   'global': 923,
#   'd1': 924,
#   'calcaneum': 925,
#   'ulcer': 926,
#   'hand': 927,
#   'neurosensory': 928,
#   'as': 929,
#   'axillary': 930,
#   'hemisphere': 931,
#   'previous': 932,
#   'tendon': 933,
#   'situ': 934,
#   'spondylolisthesis': 935,
#   'colic': 936,
#   'posterosuperior': 937,
#   'differentiated': 938,
#   'csh': 939,
#   'subependymal': 940,
#   'component': 941,
#   'identified': 942,
#   'can': 943,
#   'outgrowth': 944,
#   'hypothalamus': 945,
#   'foraminal': 946,
#   'ducts': 947,
#   'projecting': 948,
#   'highdensity': 949,
#   'mal': 950,
#   'flow': 951,
#   'peritendinous': 952,
#   'peritonei': 953,
#   'anteroposterio': 954,
#   'orbital': 955,
#   'intrathecal': 956,
#   'spectroscopy': 957,
#   'ankylosis': 958,
#   'hiatus': 959,
#   'testis': 960,
#   'displacing': 961,
#   'rectus': 962,
#   'Peritoneal': 963,
#   'joint': 964,
#   'pneumatized': 965,
#   'eccentric': 966,
#   'gallery': 967,
#   'laryngoceles': 968,
#   'relative': 969,
#   'wi': 970,
#   'cradle': 971,
#   'chiari': 972,
#   'good': 973,
#   'transmural': 974,
#   'clavicula': 975,
#   'cystoides': 976,
#   'intencity': 977,
#   'atypical': 978,
#   'habitual': 979,
#   't2w': 980,
#   'spondylotic': 981,
#   'sacral': 982,
#   'void': 983,
#   'heterogenous': 984,
#   'ischemia': 985,
#   'mouth': 986,
#   'resembling': 987,
#   'Postcontrast': 988,
#   'facets': 989,
#   'lunate': 990,
#   'putamen': 991,
#   'Cardiac': 992,
#   'multilayered': 993,
#   'evolving': 994,
#   'cystogram': 995,
#   'prolonged': 996,
#   'petroclival': 997,
#   'hypoattenuating': 998,
#   'necessary': 999,
#   ...},
#  'ix_to_ans': {0: 'renal hypoperfusion',
#   1: 'spinal fracture dislocation of t6 to t7',
#   2: 'in the parietal region',
#   3: 'the narrow angle between the aorta and the sma',
#   4: 'l5 vertebra',
#   5: 'abdominal ct with arrows',
#   6: 'swelling',
#   7: 'to the vermis',
#   8: 'anterior displacement of the dorsal dura compressing the thecal sac',
#   9: 'intravenous and oral contrast',
#   10: 'orbital cellulitis and sinusitis',
#   11: 'magnetic resonance imaging t2 sagittal section',
#   12: 'a large well defined cystic lesion in sacrococcygeal area',
#   13: 'abdomen mri',
#   14: 'of posterior aspect of globe',
#   15: 'axial HRCT scan',
#   16: 'in the specially designed hammock',
#   17: 'edema and breakdown of muscle architecture of the left thigh',
#   18: 'removal of the hematoma in the spinal canal',
#   19: 'after reintroduction of steroids',
#   20: 'a 20 21 17mm pituitary adenoma',
#   21: 'a narrowing and irregularity of the proximal luno triquetral joint space indicating a fibro cartilage coalition',
#   22: 'basal predominance',
#   23: 'ct of the abdomen prior to drain removal',
#   24: 'sagittal ct section of larynx',
#   25: 'in the right maxilla',
#   26: 'ct head',
#   27: 'bilateral symmetric ground glass appearance involving the all lung areas',
#   28: 'ct scan abdomen and pelvis',
#   29: 'calpocephaly and a rabbit ear appearance or devils horn appearance',
#   30: 'nipple sign at the level of entry of the anterior ethmoid artery into the nasal cavity',
#   31: 'axial mri of the left ankle',
#   32: 'cerebral edema',
#   33: 'contrast enhanced t1w coronal mri',
#   34: 'high density structure in the cyst',
#   35: 'contrast media extravasation and bowel loop pooling',
#   36: 'right frontoparietal chronic subdural hematoma',
#   37: 'the giant lipoma underneath the right gluteus maximus',
#   38: 'the facets in alignment',
#   39: 'each lesion',
#   40: 'due to herniation',
#   41: 't2w sagittal mri of the cervical spine',
#   42: 'mri of the left arm of the patient',
#   43: 'in the white matter of both hemispheres',
#   44: 'absence of the odontoid process',
#   45: 'evidence of predominantly right frontal cerebritis with early abscess formation',
#   46: 'severe right sided hydroureteronephrosis consistent with a high grade obstruction',
#   47: 'ct of kidneys',
#   48: 'agenesis of cerebellar vermis',
#   49: 't2 flair axial mri of the brain',
#   50: 'the anterior abdominal wall',
#   51: 'axial t2 weighted and flair mri',
#   52: 'Axial T2W MRI image',
#   53: 'thoracic ct',
#   54: 'superficial T2 bright signal compatible with inflammation involving the subcutaneous tissue down to the level of the deep fascia',
#   55: 'in right parieto temporal white matter',
#   56: 'a 10 mm vent in the left posterolateral wall of the thoracic descending aorta',
#   57: 'with wall thickening',
#   58: 'enlarged basal cisterns and fourth ventricle',
#   59: 'a wispy ill defined embolus in the upper lobar artery',
#   60: 'the right fronto polar region on t2 image',
#   61: 'The hepatic hemangioma',
#   62: 'symmetric, high intensity signal in the pons with sparing of the peripheral portion',
#   63: '30 mm in diameter',
#   64: 'long segment of intramedullary spinal cord t2 abnormal subtle bright signal consistent myelitis',
#   65: 'ct abdomen with pelvis with contrast',
#   66: 'the fusion defect',
#   67: 'orthotopic position and no deformation of the stent',
#   68: 'abnormal signal intensity',
#   69: 'probable bone consolidation',
#   70: 'after operation',
#   71: 'dynamic ct',
#   72: 'magnetic resonance imaging t2 weighted image of the orbit',
#   73: 'clear lungs',
#   74: 'extensive free fluid',
#   75: 'gastric intramural air suspicious for gastric emphysema with a small amount of air in peri gastric veins',
#   76: 'in the area of cortical thinning',
#   77: 'within the descending colon',
#   78: 'ct scan of the abdomen',
#   79: 'multiloculated mass in the left lobe of the liver',
#   80: 'aneurysm affecting the main pulmonary artery',
#   81: 'Thick prominent enhancement',
#   82: 'ct of the chest abdomen and pelvis',
#   83: 'bilateral infarcted kidneys due to intrarenal vascular thrombosis',
#   84: 'surrounding renal cortex and parapelvic fluid',
#   85: 'cystic mass in the bilateral intervertebral foramen between 12th thoracal and 1st lumbar vertebrae',
#   86: 'basilar invagination, atlantoaxial dislocation, and chiari malformation',
#   87: 'large pyometra with intra uterine contraceptive device in situ',
#   88: 'the right hilar mass and the right sided interlobular septal thickening',
#   89: 'of the sss',
#   90: 't2w1 of mri of lumbasacral spine',
#   91: 'with evidence of fusion',
#   92: 'right-sided abdominal wall collection with fish bone',
#   93: 'a large retroperitoneal pelvic mass',
#   94: 'subcutaneous emphysema, bilateral pneumothorax, tension pneumopericardium and compressed heart',
#   95: 'the complex heterogeneous collection posterior to the anterior abdominal wall',
#   96: 'external compression of the bladder by the abdominal aortic and internal iliac artery aneurysm',
#   97: 'unenhanced ct scan of the brain',
#   98: 'a mass that demonstrates moderate homogenous hyperintensity',
#   99: 'at the level of c6 c7',
#   100: 'primary tumor of left kidney',
#   101: 'contrast-enhanced ct image',
#   102: 'erosion of the cortical bone in the right mandibular ramus',
#   103: 'the magnetic resonance imaging of cranium',
#   104: 'in the peritoneal cavity',
#   105: 'actual bleeding',
#   106: 'partial reduction of a metastatic mass in the bilateral internal auditory canals',
#   107: 'in both lateral ventricles with hydrocephalus',
#   108: 'tumor cavity',
#   109: 'mri t2 cuts',
#   110: 'marked progression of the subcutaneous metastases',
#   111: 'pet images',
#   112: 'right-sided abdominal wall collection with fish bone just visible as a hyperdense dot just anterior to the liver',
#   113: 'of the spleen',
#   114: 'a contrastfilled vagina',
#   115: 'a rim enhancing fluid collection containing a small air bubble',
#   116: 'in the appendix nodule',
#   117: 'muscle and subcutaneous oedema',
#   118: 'a ventral subdural collection at c2-t1',
#   119: 'cect scan of the abdomen',
#   120: 'an enhanced lesion of the left hard palate with thickening of the genal mucosa and no bone involvement',
#   121: 'only modest malalignment and the naked facet sign',
#   122: 'intact rotator',
#   123: 'a low density giant mass 13 cm in size and high density ascites',
#   124: 'the heterogenous vascular lesion involving the right masseter',
#   125: 'site and size of infarct in three study patients',
#   126: 'hyperdense mass in left maxillary sinus and thinning of infra orbital margin',
#   127: 'a degenerative signal loss with mild height reduction',
#   128: 'diffuse colonic calcification',
#   129: 'cardiophrenic sparing',
#   130: 'regional lymph node involvement',
#   131: 'focal atrophy of the left temporal lobe',
#   132: 'between liver and upper pole of right kidney',
#   133: 'hemorrhagic infarction of the left temporal lobe',
#   134: 'minimal aerated lung',
#   135: 'coronal reconstructed ct of the odontoid complex',
#   136: 'postoperative saggital mri of the thoracolumbar region',
#   137: 'pneumobilia',
#   138: 'multiple calcified nodules',
#   139: 'the t2 weighted image',
#   140: 'luminal narrowing',
#   141: 'a liver cyst',
#   142: 'a focal lesion bulging out of the posterior gastric wall',
#   143: 'a large consolidation area and peripheral ground glass opacities in left lower lobe',
#   144: 'coiled shunt',
#   145: 'of the right femoral head',
#   146: 'axial ct scan of the paranasal sinus with contrast',
#   147: 'brain mri t2 bilateral parieto-occipital',
#   148: 'abscess collection in relation to the left sciatic nerve',
#   149: 'magnetic resonance angiography in the coronal view',
#   150: 'by two thin walled fluid collections',
#   151: 'in the upper outer quadrant of the breast',
#   152: 'a seemingly diffuse infiltrative non enhancing mid brain lesion on the ct scan',
#   153: 'no oral contrast media leaking from the cecum into the peritoneal cavity',
#   154: 'significant thickening and distortion with lytic areas',
#   155: 'the left iliaca fossa',
#   156: 'of low attenuation in right lobe of liver',
#   157: 'of screwdriver abutting the abdominal aorta',
#   158: 'bilateral parietoccipital hyperintense signals',
#   159: 'extensive myelitis',
#   160: 'the ct scan',
#   161: 'the left parotid gland mass in the coronal plane',
#   162: 'mri scan of the thorax',
#   163: 'reformatted picture on ct scan',
#   164: 'csf accumulation at right middle ear',
#   165: 'a low lying tethered cord',
#   166: 'axial cut of mri scan',
#   167: 'multiple abscesses in the liver',
#   168: 'over l5 s1 level',
#   169: 'diffuse and asymmetrical thickening of the vesical wall',
#   170: 'normal appearing ileum at ileo caecal junction',
#   171: 'reformatted coronal post contrast thin section ct scan',
#   172: 'sidearm graft occlusion',
#   173: 'of infra orbital margin',
#   174: 'along the synovial lining of the knee joint',
#   175: 'peripheral enhancement',
#   176: 'in the right parasagittal section',
#   177: 'tubular hypointensity',
#   178: 'Sagittal and axial T2-weighted MRI image of atlantoaxial chordoma',
#   179: 'pneumomediastinum, pneumopericardium and surgical emphysema',
#   180: 'cystic components of vertebra l4',
#   181: 't2 weighted coronal and axial magnetic resonance images',
#   182: 'on the posterior bladder wall',
#   183: 'the amygdala and part of the head of the hippocampus',
#   184: 'the hypo intense signal in the t2 weighted image',
#   185: 'bilateral impacted neck of femur fracture',
#   186: 'subdural hematoma',
#   187: 'a magnetic resonance image',
#   188: 'postoperative ct angiogram of brain',
#   189: 'no further progressive divertion flow to the aneurysm or changes',
#   190: 'in the right ovarian vein',
#   191: 'increased height of medial meniscus cartilage and articular cartilage',
#   192: 'a relatively well defined lesion of hyperintensive signals in a t2 weighted image, and no soft tissue extension',
#   193: 'a large complex cystic and solid mass in the body and tail of the pancreas',
#   194: 'ct scan at the end of treatment',
#   195: 'magnetic resonance imaging of brain with contrast',
#   196: 'of the mass',
#   197: 'edematous changes in adipose tissue of the upper side of the left foot',
#   198: 't2 weighted sagittal magnetic resonance scan',
#   199: 'around the distal oesophagus',
#   200: 'abdominal aortic aneurysm',
#   201: 'at t12 l1 disc',
#   202: 'a t2 weighted magnetic resonance image',
#   203: 'through the torn intercostal muscles',
#   204: 'mixed signals for the straight sinus and vein of galen and corpus callosum splenium swelling',
#   205: 'enhanced abdominal ct',
#   206: 'area of necrosis seen in the tail region',
#   207: 'the fish bone transversely located at the right sternocleidomastoid muscle',
#   208: 'fixation',
#   209: 'the typical molar tooth configuration of the superior cerebellar peduncles',
#   210: 'dorsal pancreatic duct and ventral pancreatic duct',
#   211: 'congestion of the retro orbital space and enlargement of the extraocular muscles',
#   212: 'in the little finger',
#   213: 'coronal view of ct scan of the abdomen and pelvis',
#   214: 'loculated fluid collection contiguous with the gluteus medius and pyriformis muscles',
#   215: 'in both sides',
#   216: 'along the anteromedial aspect of long shaft of femur',
#   217: 'in the distal ileum',
#   218: 't1 weighted transverse magnetic resonance image of the right lower extremity',
#   219: 'without evidence of an abnormal airspace filling process',
#   220: 'axial brain mri in flair sequence',
#   221: 'eradication of the varices from the descending colon',
#   222: 'axial diffusion weighted imaging magnetic resonance imaging',
#   223: 'good opacification of the small and large bowel with thickening of the inflamed cecal wall',
#   224: 'axial t2w mri image of the brain',
#   225: 'on the thumb',
#   226: 'coronal slice of ct scan',
#   227: 'sagittal t2 weighted mri scan',
#   228: 'an intact cranioplasty site',
#   229: 'ct scan',
#   230: 'a bifrontal dural based lesion with involvement of the falx',
#   231: 'the lateral lamellae',
#   232: 'syrinx in the cervical and dorsal regions',
#   233: 'bone metastases that was not detected by standard radiology such as ct or mri',
#   234: 'anomalous origin of right coronary artery from pulmonary artery',
#   235: 'the stretched adherent uterus with increased utero cervical length',
#   236: 'cerebellar enhancing lesions with secondary hydrocephalus',
#   237: 'the ruq appendiceal abscess',
#   238: 'annular disruption',
#   239: 'of hyperintense signal',
#   240: 'pneumoperitoneum',
#   241: 'pancreatic parenchyme',
#   242: 'mri of the lower abdomen and pelvis',
#   243: 'thickened pericardium',
#   244: 'multiple intramural fibroids',
#   245: 'radiological features of emvi',
#   246: 'in both lungs',
#   247: 'the odontoid process and atlantoaxial instability',
#   248: '3d ct of the external aspect of the jaw',
#   249: 'the lateral ventricles',
#   250: 'a large solid cystic lesion in left parieto occipital area enhancing on contrast',
#   251: 'a left tubo ovarian mass suggestive of a neoplastic mass',
#   252: 'in the right orbit',
#   253: 'new process developed in the cns',
#   254: 'sagittal and coronal mri imaging of the cervical spine',
#   255: 'a curved rim of hypodense mass pointing between left internal and external carotid arteries',
#   256: 'the prostatic neoplasm',
#   257: 'the dimensions of the tumor',
#   258: 'distributed in the left pericardium',
#   259: 'a triangular lesion of the corpus callosum with signs of leukoencephalopathy',
#   260: 'a complete process of reparation of the lesion of the proximal insertion of the mcl',
#   261: 'in the femoral inter condylar notch',
#   262: 'ct scan brain image',
#   263: 'axial mri through the sphenoid sinus on t1 with gadolinium,',
#   264: 'of the lesions',
#   265: 'the abnormal location of an infarcted spleen within the pelvis',
#   266: 'into right l4 l5 foramen',
#   267: 'small and narrow airway of choanal space',
#   268: 'ruptured artery supplying the interpole',
#   269: 'heterogeneous soft tissue',
#   270: 'no associated cervical kyphosis',
#   271: 'thickened cortex with altered signal intensity involving the right humerus head and proximal shaft',
#   272: 'ct',
#   273: 'contrast magnetic resonance imaging of the brain',
#   274: 'abnormal bone in the lateral femoral condyle and the adjacent tibial plateau',
#   275: 'in the left hepatic lobe with rupture in the biliary tract',
#   276: 'an area of increased signal intensity compatible with myocardial fatty substitution',
#   277: 'outside the dose grid region',
#   278: 'flair sequence mri',
#   279: 'coronal section magnetic resonance imaging of hypothalamo pituitary region',
#   280: 'the complete absence of the subgaleal hematoma',
#   281: 'typical presentation of nbd',
#   282: 'pneumoscrotum',
#   283: 'on this ct scan',
#   284: 'in the left frontal and frontoparietal regions',
#   285: 'high intencity signals in periventricular white matter and midbrain',
#   286: 'ct aortography with 3d reconstruction',
#   287: 'mri cvj region stir midsagittal image',
#   288: 'without infiltration',
#   289: 'multiple para aortic lymphadenopathy',
#   290: 't2 weighted mri',
#   291: 'complete anterior sublaxation',
#   292: 'larynx',
#   293: 'to the subcutaneous tissue, and osteomyelitis in the adjacent bone',
#   294: 'admission mri of the patient',
#   295: 'an ectopic pelvic location of the kidney',
#   296: 'ct angiogram of the abdomen',
#   297: 'a sagittal section of a ct scan',
#   298: 'the point of cord impingement',
#   299: 'in the left temporo-parietal region',
#   300: 'the enlarged, distended uterine horns and adnexal structures',
#   301: 'anterior osteophytes',
#   302: 'in the left atrium',
#   303: 'the presence of a large solid cystic serosal based pelvic mass',
#   304: 'that the entire main and branching pancreatic ducts were markedly dilated and pancreatic parenchyme was severely atrophied',
#   305: 'the subcortical edema',
#   306: 'bronchiectatic cavity of old tuberculosis which grew nocardia',
#   307: 'of the aneurysm',
#   308: 'the tumoral process infiltrated the base of the prostate gland',
#   309: 'flair magnetic resonance imaging',
#   310: 'recurrent prolactinoma',
#   311: 'ct angiogram',
#   312: 'over left hip joint',
#   313: 'mri t2 weighted sequence of the cervical mri',
#   314: 'preoperative t2w magnetic resonance imaging',
#   315: 'the procedure was completed without facetal or transverse foramen violation',
#   316: 'no evidence of abnormalities or where to target the biopsy',
#   317: 'of the thrombus',
#   318: 'pituitary gland',
#   319: 'the extent into the antrum',
#   320: 'up to the pleural surface',
#   321: 'through to the posterior portion of the c2 end plate',
#   322: 'in the superficial and deep fascia of the left leg',
#   323: 'a large fluid collection arising from left thyroid mass',
#   324: 'calculus and mass',
#   325: 'a round hyperintense cystic area with surrounding vasogenic edema, and orbital involvement along with left to right midline shift due to mass effect',
#   326: 'massive destruction of the sphenoid bone',
#   327: 'in the distal common bile duct',
#   328: 'of non ionic cm',
#   329: 'mri t2 coronal and transversal images',
#   330: 'axial and coronal magnetic resonance images with contrast',
#   331: 'bilateral renal infarcts that are predominant on the right side',
#   332: 'mri scan of the penis',
#   333: 'without signs of extrabronchial infiltration',
#   334: 'soft tissue mass in the sternum',
#   335: 'axial contrast enhanced ct and a pulmonary angiogram',
#   336: 'of encephalocele or active csf leak',
#   337: 'an enlarged rounded right level ii node with necrotic foci and ill defined margins',
#   338: 'the jejunal varices',
#   339: 'in the conus cauda',
#   340: 'a contrast enhanced ct scan of the abdomen',
#   341: 'tab gauze in pelvis',
#   342: 'noncontrast transverse ct image',
#   343: 'normal optic nerve in both sides',
#   344: 'extraskeletal bone formation',
#   345: 'the shape of ossification',
#   346: 'axial sequence of the posterior fossa',
#   347: 'a right sided maxillary sinus tumor',
#   348: 'in the left hemithorax',
#   349: 'the axillary tumor',
#   350: 'no enhancement of the lesion',
#   351: 'mild prominence of the prevertebral soft tissues',
#   352: 'the thrombus in the inferior vena cava',
#   353: 'a massive hemothorax in the left pleural space',
#   354: 'a para aortic lymph nodal mass',
#   355: 'bleeding in the myelum at the level of c3 and c4',
#   356: 'the mr scan of the brain using contrast medium',
#   357: 'absence of the posterior arch of c1',
#   358: 'decompression of ventricles with presence of cm1',
#   359: 'complete resolution of the biloma',
#   360: 'splenic hypointense homogenous lesion',
#   361: 'a dilated pelvi calyceal system',
#   362: 'a left epidural mass',
#   363: 'measurements of subacromial volume',
#   364: 'the lower peritoneal cavity',
#   365: 'due to paraesophageal hernia type iii',
#   366: 'bilateral periapical dental granulomas',
#   367: 'thickening of the tracheal wall',
#   368: 'postcontrast axial mri',
#   369: 'non contrast t1 weighted axial magnetic resonance images',
#   370: 'in the pancreatic body',
#   371: 'marked reduction of the tmuor size',
#   372: 'mid sagittal t1 weighted mri of the brain',
#   373: 'ct of chest',
#   374: 'cerebellar volume loss with preservation of cerebral hemispheres',
#   375: 'of blood',
#   376: 'multifocal inflammatory colonic wall thickening on the ascending colon',
#   377: 'atrophy pituitary glands with preserved infundibulum and hypothalamus',
#   378: 'ct scan of abdomen and pelvis',
#   379: 'the disc behind the body of C6 vertebra',
#   380: 'a stone within an area of bowel',
#   381: 'gallstones in the biliary tract with normal position of the liver and gallbladder',
#   382: 'Sagittal MRI scan of the intrauterine fetus',
#   383: 'well defined hyperintense lesion in the lower eye lid pushing the eye ball upward',
#   384: 'oct scan of the left eye',
#   385: 'Abdominal CT scan with intravenous contrast',
#   386: 't2 weighted sagittal magnetic resonance imaging',
#   387: 'a clearly enlarged lacrimal gland with ill defined margins',
#   388: 'this series of ct scans',
#   389: 'the lesion is slightly to the right of the midline',
#   390: 'generalized hypodensity with near complete obliteration of ventricular systems, basal cisterns, and sulcal spaces',
#   391: 'distal migration of pancreatic stones with diminished ductal dilatation',
#   392: 'the disc behind the body of c4 cervical vertebra appearing as hyperintense signal density',
#   393: 'on the right side with herniation of the left lung',
#   394: 'of external iliac artery',
#   395: 'of the pedicle screws at l3 and l5',
#   396: 'of the harvested graft',
#   397: 'a fatty mass at the center of the transplant kidney',
#   398: 'initial magnetic resonance imaging scan of the nasopharynx',
#   399: 'the bilateral zygomatic mass',
#   400: 'aortoesophageal fistula',
#   401: 'dose distribution and oars',
#   402: 'in the upper portion of IVS, anterior to the right coronary sinus of aorta',
#   403: 'trileaflet valve between left atrium and morphological right ventricle',
#   404: 'Sagittal T2W MRI image',
#   405: 'ct chest with contrast',
#   406: 'a double bladder with urinary output of both kidneys to the bladders',
#   407: 'due to pancreatitis',
#   408: 'the front part of left ventricular band was more hypertrophy than its right counterpart',
#   409: 'hypodens lesion with same surrounding hyperdensity at coracoglenoid junction',
#   410: 'arrow in the MRI coronal section T1 + Gadolinium',
#   411: 'in the anterior and left side of the neck',
#   412: 'significant radiological improvement in terms of clearance of calcifications',
#   413: 'coronal image in portal phase',
#   414: 'preoperative axial ct of the left knee',
#   415: 'the left nasal cavity and ethmoid sinuses',
#   416: 'an abdominal ct',
#   417: 'a calcified t7 t8 disc compressing on the spinal cord',
#   418: 'the pericardial cyst',
#   419: 'coronal reformatted ct image',
#   420: 'enhancing lesions',
#   421: 'a high-grade obstruction',
#   422: 'further ct scan of the abdomen',
#   423: 'brain mri in multiple sclerosis',
#   424: 'extraperitoneal air from the sigmoid perforation diffusing superiorly through paravertebral retroperitoneal tissue and via the diaphragmatic hiatus into the mediastinum',
#   425: 'a progressive, heterogeneous, and delayed enhancement',
#   426: 'axial and coronal ct images',
#   427: 'of the frontal bone and expansion of the frontal sinus',
#   428: 'mild periorbital swelling and edema of the extraocular muscles in the right eye',
#   429: 'at coracoglenoid junction',
#   430: 'ct and portography through ivc',
#   431: 'axial ct scan of the nose and paranasal sinuses',
#   432: 'on the right side',
#   433: 'the classic findings of a target like an ileocolic intussusception',
#   434: 'mri stir image',
#   435: 'a high density bony shadow in his left ethmoid sinus',
#   436: 'outside the greater curvature of the stomach',
#   437: 'a non occlusive saddle pulmonary embolism',
#   438: 'of the left main bronchus',
#   439: 'a large cystic mass with central low density and no mediastinal or hilar lymphadenopathy',
#   440: 'multislice ct',
#   441: 'at the afferent loop around hepaticojejunostomy site',
#   442: 'the same clinoidal meningioma',
#   443: 'bilateral ground glass opacities and crazy paving pattern',
#   444: 'neurobeh et disease',
#   445: 'of the lesion with invasive margins involving contiguous healthy bone',
#   446: 'the axial and coronal planes of the ct scan image',
#   447: 'coronal contrast enhanced t1 weighted mri at 18 months',
#   448: 'the knee',
#   449: 'old tuberculosis',
#   450: 't2 weighted magnetic resonance image of lumbar spine',
#   451: 'no sharp delineation between the tumor and the lateral lobe of the liver',
#   452: 'of the left kidney',
#   453: 'preoperative brain mri scan',
#   454: 'chest ct scan',
#   455: 'the right half of the sellar region',
#   456: 'right thalamus',
#   457: 'hematomas across the pons on both sides but no obvious lesions in the cerebellum and cerebrum',
#   458: '13 cm',
#   459: 'absent left hemi',
#   460: 'an early enhancement image with no intraductal spread',
#   461: 'of wall of the small intestine',
#   462: 'a smooth ovoid lesion in the right lower lobe',
#   463: 'the limits between the stomach and mass',
#   464: 'complete drainage without any leakage',
#   465: 'diffuse peribronchovascular thickening and small nodules bilaterally',
#   466: 'multifocal hemorrhage in the right temporal lobe and both cerebellar hemispheres',
#   467: 'mri scan of the brain',
#   468: 'septal thickening on the right side',
#   469: 'a sagittal ct scan',
#   470: 'repair of anterior skull base with bilateral calvarial bone grafts in place',
#   471: 'intraabdominal air leakage and leakage of contrast medium penetrating the liver parenchyma into the space around the spleen',
#   472: 'the human head',
#   473: 'the elbow joint in axial sections',
#   474: 'CT of a craniopharyngioma',
#   475: 'in right lobe',
#   476: 'parietal mass in anterior abdominal wall',
#   477: 'mediastinitis, bilateral pleural effusions and free air',
#   478: 'magnetic resonance imaging scan of the cervical spine',
#   479: 'post contrast coronal t1 weighted mri',
#   480: 'axial section of contrast enhanced ct of the bladder',
#   481: 'a posterior bony defect of the humeral head',
#   482: 'into subcutaneous tissue and upto bladder',
#   483: 'diskitis and vertebral signal changes suggestive of osteomyelitis',
#   484: 'extensive marrow oedema of the left pubic ramus',
#   485: 'axial post iv contrast ct through the lower chest upper abdomen',
#   486: 'in the extra-axial space',
#   487: 'within the parenchyma of the left kidney',
#   488: 't2 weighted mri of the brain',
#   489: 'of the common bile ducts with round and tubular dilatation of the intrahepatic bile ducts',
#   490: 'ct scannogram',
#   491: 'hypointense mass in the right lateral ventricle with pressure over the brain stem',
#   492: 'medullary compression and disruption of ligaments',
#   493: 'leiomyoma',
#   494: 'a heterogeneous soft tissue lesion in the porta hepatis with a dilated common bile duct',
#   495: 'The position of treatment couch removed',
#   496: 'tumor invading to the SMA and CA',
#   497: 'a radiodense trabecular pattern in the center of the lung mass',
#   498: 'magnetic resonance imaging of a patient with juvenile idiopathic arthritis',
#   499: 'magnetic resonance imaging',
#   500: 'contrast ct film',
#   501: 'enlargement of the bilateral intraocular rectus',
#   502: 'of the subgaleal hematoma',
#   503: 'mri neck',
#   504: 't2 weighted magnetic resonance imaging transverse plane of pelvis',
#   505: 'combination of fat, calcification and soft tissue',
#   506: 'internal target volume',
#   507: 'the hematoma in the left aspect of the spinal canal',
#   508: 'horseshoe kidney',
#   509: 'ct bone window',
#   510: 'retroperitoneal necrotic extensions',
#   511: 'a mass in quadrigeminal cistern',
#   512: 'with lymphomatous involvement',
#   513: 'in liver',
#   514: 'that the abscess in the submandibular and sublingual space is almost dissolved',
#   515: 'a modest stenosis within the anterior and posterior circulation',
#   516: 'within the muscles of the right cheek',
#   517: 'a retroperitoneal mass on the left side of the aorta compressing the left renal vein',
#   518: 'without stenosis',
#   519: 'carotid vessels',
#   520: 'a non contrast ct abdomen',
#   521: 'the pseudoaneurysm of external iliac artery',
#   522: 'lesions over pelvis',
#   523: 'in theaortopulmonary window',
#   524: 'postoperative axial t1 and sagittal t2 weighted magnetic resonance images',
#   525: 'multiple sinuses extending till the underlying muscles',
#   526: 'axial contrast enhanced ct image of trachea on lung windows',
#   527: ' over the site of endoscopic hernioplasty',
#   528: 'thickening of the aortic wall',
#   529: 't2 weighted magnetic resonance imaging with the head in extension position',
#   530: 't2 weighted magnetic resonance images',
#   531: 'an ex vivo human lung',
#   532: 'left paraduodenal hernia',
#   533: 'spiral ct scan of the chest',
#   534: 'abnormal rotation of the proximal jejunum',
#   535: 'in d11 involving the upper vertebra as well',
#   536: 'at the t10 level',
#   537: 'homogenously enhancing omental and left lumbar lesions',
#   538: 'Coronal T2-weighted MRI',
#   539: 'hyperintensity of splenium of corpus callosum',
#   540: 'a hyperdense lesion in the right anterior abdominal wall',
#   541: 'contrast enhanced ct during the arterial phase',
#   542: 'medial meniscus',
#   543: 'in the gastrohepatic and duodenal compartments',
#   544: 'wall thickening in several distal small bowel loops and cecum',
#   545: 'axial contrast enhanced ct image through the abdomen',
#   546: 'mri guided biopsy',
#   547: 'in the left maxillary antrum',
#   548: 'no abnormality in inferior olive',
#   549: 'right parietal regions',
#   550: 'the case of a tuberculum sellae meningioma',
# ...
#   704: 'septate uterus',
#   705: 'the encircling gastric wall thickening',
#   706: 'of the nail in the abdomen',
#   707: 'mri picture',
#   708: 'flair weighted mri sequences of two patients',
#   709: 'hyperintense signal changes in right internal capsule and basal ganglionic region',
#   710: 'ct chest angiogram',
#   711: 'at porta with ihbr dilatation',
#   712: 'at porta with intrahepatic biliary radical dilatation',
#   713: 'cect scan of thorax',
#   714: 'the absence of significant tracheal compression',
#   715: 'of the spinal cord from t4 downwards with foci of t2w hyperintensity and meningeal enhancement',
#   716: 'extension of lesion',
#   717: 'probable cartilage regeneration',
#   718: 'bilateral and symmetric hyperintensity of striatum and hyperintensity of the right insular cortex on flair image',
#   719: 'same pons infarct',
#   720: 'successful obliteration of all aneurysms',
#   721: 'a left renal mass',
#   722: 'bilateral severe pleural effusions and right pleural chest drain insertion',
#   723: 'agenesis of cerebellar vermis causing the molar tooth sign',
#   724: 'ct myelogram',
#   725: 'mri brain axial section',
#   726: 'a unilocular, well-defined and high signal intensity cystic lesion with hypointense rim',
#   727: 'axial t2 weighted magnetic resonance image',
#   728: 'ct reconstruction picture',
#   729: 'a 12 by 13 by 10 cm mass in the pelvis',
#   730: 'the shunt tube',
#   731: 'irregular dilatation of common bile',
#   732: 'in the region anterior to the sacrum',
#   733: 'mri abdomen',
#   734: 'wedge shaped non enhancing defect involving left inter polar region suggesting renal infarction',
#   735: 't2-weighed sagittal mri',
#   736: 'the diffuse atrophy in the cerebellum',
#   737: 'in the left adnexa with macro calcifications and enhancement of the solid components',
#   738: 'axial mri imaging of the craniocervical junction',
#   739: 'of lesions',
#   740: 'a large right csh',
#   741: 'multiple abscesses',
#   742: 'extensive stenosis of more cervical vessels',
#   743: 'paraaortic lymphangiectasia',
#   744: 'between bladder, uterus and vagina',
#   745: 'Axial, coronal, sagittal CT without contrast',
#   746: 'bilateral ground glass infiltrates',
#   747: 'to the pelvis',
#   748: 'a mass',
#   749: 'two of several contrast enhancing leptomeningeal metastases',
#   750: 'behind the distended bladder',
#   751: 'ct coronal',
#   752: 'occlusion and dilatation of left transverse and lateral sinus',
#   753: 'the separation of the units',
#   754: 'no',
#   755: 'a cortical-based mass lesion at the medial aspect of the right temporal lobe',
#   756: 'a multiseptated cyst at the inferior aspect of the glenoid neck and a suspected labral tear',
#   757: 'an ongoing process of reparation of the lesion of the proximal insertion of the mcl',
#   758: 'magnetic resonance imaging t1 weighted image',
#   759: 'in the right lateral-upper quadrant, an irregularly shaped, 2,5 cm tumor showing peripheral ring-shaped contrast enhancement',
#   760: 'large retroperitoneal mass',
#   761: 'a hematoma in the left temporo parietal region and two enhancing nodular lesions in the right frontal and left temporal regions',
#   762: 'enhanced wall thickening in the anterior wall midline',
#   763: 'of emvi',
#   764: 'sagittal reformat ct image',
#   765: 'lesion in the left maxillary sinus with nasal septum deviation',
#   766: 'after barium sulfate injection into an intraosseous access',
#   767: '1.2 cm',
#   768: 'pulmonary embolus',
#   769: 'gadolinium enhanced cranial magnetic resonance imaging',
#   770: 'the involvement of the right iliac crest',
#   771: 'a large soft tissue mass on the anterolateral part of the right thigh',
#   772: 'a mass in the medullary canal',
#   773: 'a subarachnoid hemorrhage on the anterior portion of the basal cistern',
#   774: 'the infarct',
#   775: 'multiple nodular lesions with cavitation',
#   776: 'postoperative contrast enhanced ct scan',
#   777: 'a cystic tumor of the pancreatic head and body',
#   778: 'the coil mass in the left internal auditory meatus',
#   779: 'narrowing of celiac axis beyond its origin',
#   780: ' multiple cutaneous neurofibromas',
#   781: 'in canal',
#   782: 'canal encroachment',
#   783: 'axial ct angiographic image',
#   784: 'the acl graft and a possible tibial cyclops lesion',
#   785: 'coronal and axial views of the intraspinal and extraspinal soft tissue mass at t2 t3',
#   786: 'coronal t2 magnetic resonance imaging sequence of upper legs',
#   787: 't2 weighted mri image',
#   788: 'no abnormalities',
#   789: 'a mass shadow',
#   790: 'magnetic resonance scanning of discussed patient',
#   791: 'anophthalmia with marked inflammation of right medial orbital wall and lateral displacement of right medial rectus',
#   792: 'a mass between stomach and kidney',
#   793: 'subligamentous extension of inflammation to the t12 l1 intervertebral disc',
#   794: 'coronal ct scan of the orbit at the mid orbit level',
#   795: 'the ureterovaginal fistula',
#   796: 'ct scan of cv junction after fixation',
#   797: 'a computed tomography image',
#   798: 'the left lung',
#   799: 'ct scan of the right wrist',
#   800: 'nearly complete resolution of the lesions',
#   801: 'a peripheral rim enhancement of the lesion',
#   802: 't2 weighted mri of thoracic spine',
#   803: 'axial contrast enhanced ct scan of the liver done in may 2004',
#   804: 'large ischaemic infarct in the right parietal lobe',
#   805: 'diffuse interstitial lung disease with septal interstitial thickening',
#   806: 'ct post chemotherapy',
#   807: 'the nasal septum',
#   808: 'within the right mastoid air cells',
#   809: 'diverticular out pouchings and bronchomegaly',
#   810: 'vertebra l4',
#   811: 'of the dorsal dura compressing the thecal sac',
#   812: 'Hyperintense well-defined mass at the C2-C3 level of cervical spinal cord with wide dural attachment',
#   813: 'Abdominal CT scan of complicated diverticulitis',
#   814: 'atypical presentations of neurobeh et disease',
#   815: 'solid nature',
#   816: 'contrast enhanced ct scan of thorax',
#   817: 'extension of inflammation',
#   818: 'in the medial malleolus',
#   819: 'a large right sided perinephric fluid collection',
#   820: 'extension to the orbit',
#   821: 'pleural based soft tissue density and a right lower lobe mass',
#   822: 'coronal ct scan of pelvis',
#   823: 'the thrombosis of the superiormesenteric vein',
#   824: 'between 2 and 5 cm',
#   825: 'situs inversus',
#   826: 'edema and breakdown of muscle architecture',
#   827: 'in anterior abdominal wall',
#   828: 'the collection was superficial to the muscles of the back and the gluteal region but deep to the posterior layer of the thoraco lumbar fascia',
#   829: 'bone marrow edema adjacent to the fibro-cartilage coalition',
#   830: 'the molar tooth sign',
#   831: 'of the varices from the descending colon',
#   832: 'normal post operative changes',
#   833: 'an axial non enhanced temporal bone ct',
#   834: 'Meningitis related bifrontal/bitemporal subdural empyema',
#   835: 'empty right lateral sinus',
#   836: 'dilated pulmonary vasculature',
#   837: 'the lesion in the proximal tibia',
#   838: 'crashed midface fracture',
#   839: 'complex fluid collection with layering consistent with hematoma',
#   840: 'in the tail of pancreas',
#   841: 'ct guided biopsy of adrenal lesions',
#   842: 'enlarged left and right adrenals',
#   843: 'at the afferent loop',
#   844: 'a slide from ct abdomen',
#   845: 'arrows in the ct abdomen',
#   846: 'along the anterior gastric body',
#   847: 'of primary tumor',
#   848: 'the left internal acoustic meatus',
#   849: 'emergency ct',
#   850: 'multiple bilateral pulmonary emboli and bilateral air space',
#   851: 'an enhancing lesion extending into the cerebellopontine angle from the left internal acoustic meatus',
#   852: 'cerebral edema with thickening of the gray matter',
#   853: 'locules of gas extending into the root of the neck and a cavity beneath the mandible',
#   854: 'abdominal ct',
#   855: 'rhombus shape similar to S1 vertebra',
#   856: 'of oral contrast',
#   857: 'axial ct scan of the sinuses',
#   858: 'in right renal parenchyma with perinephric extension',
#   859: 'axial brain ct scan taken on admission',
#   860: 'mri t2 coronal and transversal sequences',
#   861: 'removal of the hematoma and decompression of the dural sac and roots',
#   862: 'coronal t2 weighted mri',
#   863: 'ct of the thorax after one year treatment',
#   864: 'into pleura with multiple small nodules on left side',
#   865: 'of posterior pituitary bright spot',
#   866: 'a dense nidus of central calcification in an adenocarcinoma of the lung',
#   867: 'a significant decrease in the extent of involvement',
#   868: 'absence of liver involvement',
#   869: 'pancreatic calcifications and mass',
#   870: 'bilateral giant renal masses consisting predominantly of fat tissue',
#   871: 'a left saccular infrarenal aortic aneurysm',
#   872: 'intramedullary hyperintense lesion',
#   873: 'an encapsulated mass',
#   874: 'periacetabular bone loss',
#   875: 'the extension of the hematoma from within the retrocrural space to the right pleural space, and the extravasation of the retrocrural space',
#   876: 'evidence of free air with free fluid adjacent to the transverse colon',
#   877: 'the obstructed ureter',
#   878: 'marked intra abdominal lymph leakage postoperatively with organ compression and abdominal compartment syndrome',
#   879: 'multiple fragments of the disc behind the body of c6 vertebra seen as isointense signal density',
#   880: 'no pericardial effusion but bilateral lung metastasis with pleural effusion',
#   881: 'marked improvement, mainly in putamen',
#   882: 'hyperintensities in periventricular areas',
#   883: 'left lingular malignancy and no evidence of metastasis',
#   884: 'straightening of the interventricular septum',
#   885: 'ct scan of chest with contrast',
#   886: 'initial gadolinium enhanced axial magnetic resonance image of case 3',
#   887: '2,5 cm',
#   888: 'preoperative sagittal t2 weighted magnetic resonance images',
#   889: 'T1-weighted MRI with contrast axial view',
#   890: 'in periventricular white matter and midbrain',
#   891: 'branching hypodense lesions due to hepatic necrosis',
#   892: 'in front of the pancreas body',
#   893: 'corpus callosum lipoma with intraventricular extension',
#   894: 'Type A basilar invagination',
#   895: 'atlantooccipital fusion and fusion of the c4 c6 vertebrae',
#   896: 'initial axial ct at the mid abdominal level',
#   897: 'spinal mri',
#   898: 'hypo dense masses',
#   899: 'TL1',
#   900: 'a rim enhancing fluid collection with small bubbles of air anteriorly',
#   901: 'the fibroadipose tissue',
#   902: 'mri findings and a t2 weight image',
#   903: 'multiple, hypodense, focal lesions in both lobes of the liver with fatty attenuation',
#   904: 'the t1 weighted image of magnetic resonance imaging of the left thigh',
#   905: 'a solid right lower pole mass',
#   906: 'case 11 mri brain with contrast',
#   907: 'nonspecific findings including multiple white matter low densities',
#   908: 'massive acute ischemic infarct',
#   909: 'ct scan of a brain',
#   910: 'the absence of the lesion and postoperative changes',
#   911: 'into the medulla',
#   912: 'extensive involvement of the spinal cord from t4 downwards with foci of t2w hyperintensity and meningeal enhancement',
#   913: 'helical ct examination of heterogeneous, cystic renal mass within the left retroperitoneal site',
#   914: 'the portal vein thrombosis',
#   915: 'a soft tissue defect and severe muscular inflammatory infiltration around bone',
#   916: 'in the right side of the intra abdomen',
#   917: 'the inferio lateral displacement of the right bulbus oculi',
#   918: 'the olfactory fossae',
#   919: 'in right upper lobe of lung',
#   920: 'noncontrast enhanced ct of brain at supraclinoid level',
#   921: 'coronal ct scan of the orbits',
#   922: 'a metallic foreign body in middle ear',
#   923: 'an intra cardiac mass in the anterior side of the right atrial wall encasing a right coronary artery',
#   924: 'barium sulfate injection into an intraosseous access',
#   925: 'within the cavity',
#   926: 'the extent of epidural abscess',
#   927: 'axial unenhanced ct image of the abdomen',
#   928: 'axial reconstruction from a ct scan upon patient arrival',
#   929: 'the severe compression of the cord',
#   930: 'a cerebellum metastasis',
#   931: 'a hypo intense cystic mass in the posterior soft tissue',
#   932: 'magnetic resonance myelogram',
#   933: 'a mass measuring 10-30 mm in the hilar bile duct',
#   934: 'of the cervical great vessels',
#   935: 'pet ct scan of chest',
#   936: 'axial magnetic resonance image',
#   937: 'the right common femoral vein compared by the normal left common femoral vein',
#   938: 'at the left iliac bone and at the left sacral wing',
#   939: 'a duplicated ivc',
#   940: 'post contrast images',
#   941: 'sphenoid septa attached to the bony walls of type iii optic nerve bilaterally',
#   942: 'a solid tumor mass in the right kidney',
#   943: 'at the upper pole of the transplanted kidney',
#   944: 'mural thickening in the ascending colon',
#   945: 'at the inferior section of both parietal lobes',
#   946: 'lowest level of spinal cord',
#   947: 'abdomen ct',
#   948: 'surasellar extension',
#   949: 'muscle architecture of the left thigh',
#   950: 'a splenic abscess communicating with another subcutaneous abscess through the lower chest wall',
#   951: 'ct scan with 3d reconstruction',
#   952: 'evidence of a contained rupture',
#   953: 'axial t2w mri of the brain',
#   954: 'a lumbosacral mri sagittal plane image',
#   955: 'in posterior part of spinal cord',
#   956: 'the ld flap',
#   957: 'collection anterior',
#   958: 't2 weighted magnetic resonance imaging coronal plane of pelvis',
#   959: 'non enhancing lesion in the tail of pancreas',
#   960: 'three dimensional ct image of choanal air airway',
#   961: 'in frontal and temporal regions',
#   962: 'false and true lumens of the ascending aorta',
#   963: 'a mass occupying almost the entire nasopharyngeal space',
#   964: 'the right kidney having irregular low density lesion with perirenal collection',
#   965: 'on the left side of the image',
#   966: 'at both frontoparietal lobes, the right thalamus, and both cerebellar hemispheres',
#   967: 'the oblique trajectory and the approach to axis',
#   968: 'multiple lesions located in the white matter of both hemispheres',
#   969: 'a well defined isodense to hypodense fluid collection',
#   970: 'the size of the renal mass and the thrombus',
#   971: 'epidural abscess in the right parasagittal section',
#   972: 'multiple osteolytic lesions with contrast enhancement and central necrosis',
#   973: 'axial contrast enhanced ct scan of the upper abdomen',
#   974: 'bilateral internal laryngoceles',
#   975: 'numerous bilateral poorly defined and randomly distributed small pulmonary nodules with a preferentially centrilobular location',
#   976: 'axial t2 weighted mri of brain at the level of basal ganglia',
#   977: 'hypodense lesions in the right basal ganglia',
#   978: 'noncontrast ct scan of the head',
#   979: 'hypointense areas suggestive of fat',
#   980: 'the irregular hypodense lesion with fat stranding nearby the cecum without obvious enlarged lymph nodes',
#   981: 'without evidence of dissection',
#   982: 'mri of the pelvis',
#   983: 'nocardia',
#   984: 'ct with mediastinal window',
#   985: 'ct chest',
#   986: 'dextrocardia with situs solitus',
#   987: 'remodelling in partially sclerotic bone',
#   988: 'of the small and large bowel with thickening of the inflamed cecal wall',
#   989: 'a well defined depression on the superior aspect of the body of c2 with non visualization of the dens',
#   990: 'Peritoneal free air',
#   991: 'homogenous intensity of the accessory center',
#   992: 'head of pancreas, as well as hepatic and renal cysts',
#   993: 'of hyper intensity involving caudate nucleus and thalamus',
#   994: 'magnetic resonance image of the brain',
#   995: 'beside the right wall of the uterus',
#   996: 'an expansive mass arising from the nasal septum',
#   997: 't2 weighted image of mri brain',
#   998: 'lesion in the right breast and moderate right axillary lymphadenopathy',
#   999: 'pineal tumor which is enhancing brightly with hydrocephalus with signifiant periventricular ooze',
#   ...}}

# %% [markdown]
# ### Creating the model

# %% [markdown]
# #### The functions the gets the model:

# %% [markdown]
# ##### Get Embedding:

# %%
import numpy as np
import random
import h5py
def prepare_embeddings(metadata):
    embedding_filename = embedding_matrix_filename
    num_words = len(metadata['ix_to_word'].keys())
    dim_embedding = embedding_dim



    logger.debug("Embedding Data...")
    # texts = df['question']

    embeddings_index = {}
    i = -1
    line = "NO DATA"


    glove_line_count = File.file_len(glove_path, encoding="utf8")
    def process_line(i, line):
        print_progress(i, glove_line_count)
        try:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
            print_progress(i+1, glove_line_count)
        except Exception as ex:
            logger.error(
                "An error occurred while working on glove file [line {0}]:\n"
                "Line text:\t{1}\nGlove path:\t{2}\n"
                "{3}".format(
                    i, line, glove_path, ex))
            raise


    # with open(glove_path, 'r') as glove_file:
    with VerboseTimer("Embedding"):
        with open(glove_path, 'r', encoding="utf8") as glove_file:
            [process_line(i=i, line=line)for i, line in enumerate(glove_file)]



    embedding_matrix = np.zeros((num_words, dim_embedding))
    word_index = metadata['ix_to_word']

    with VerboseTimer("Creating matrix"):
        embedding_tupl = ((word, i, embeddings_index.get(word)) for word, i in word_index.items())
        embedded_with_values = [(word, i, embedding_vector) for word, i, embedding_vector in embedding_tupl if embedding_vector is not None]

        for word, i, embedding_vector in embedded_with_values:
            embedding_matrix[i] = embedding_vector


    e = {tpl[0] for tpl in embedded_with_values}
    w = set(word_index.keys())
    words_with_no_embedding = w-e
    rnd = random.sample(words_with_no_embedding , 5)
    logger.debug("{0} words did not have embedding. e.g.:\n{1}".format(len(words_with_no_embedding),rnd))

    with VerboseTimer("Dumping matrix"):
        with h5py.File(embedding_filename, 'w') as f:
            f.create_dataset('embedding_matrix', data=embedding_matrix)

    return embedding_matrix
# Out:
# c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# If the embedding already exists, save yourself the time and just load it.
# Otherwise - calculate it

# %%
if os.path.exists(embedding_matrix_filename):
    logger.debug("Embedding Data already exists. Loading...")
    with h5py.File(embedding_matrix_filename) as f:
        embedding_train = np.array(f['embedding_matrix'])    
else:
    logger.debug("Calculating Embedding...")
    embedding_train = prepare_embeddings(meta_train)
    
embedding_matrix = embedding_train
# Out:
# 20:48:27,313 pythonVQA DEBUG ## Embedding Data already exists. Loading...

# %% [markdown]
# And lets take a look:

# %%
embedding_matrix
# Out:
# array([[-0.44398999,  0.12817   , -0.25246999, ..., -0.20043001,
#         -0.082191  , -0.06255   ],
#        [ 0.08561   ,  0.077471  , -1.01680005, ..., -0.30044001,
#          0.012508  ,  0.24875   ],
#        [-0.16277   ,  0.033858  , -0.39416999, ...,  0.20255999,
#         -0.17546999, -0.30397999],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.21359   ,  0.85279   ,  0.48688999, ..., -0.19047   ,
#         -0.058526  , -0.49094   ],
#        [ 0.72328001, -0.1178    , -0.022166  , ...,  0.49592999,
#         -0.16937999, -0.58451003]])

# %% [markdown]
# And lets wrap it with related information:

# %%
from vqa_flow.data_structures import EmbeddingData
def get_embedding_data(embedding_matrix, meta_data):    
    dim = embedding_dim
    s_length = seq_length    
    return EmbeddingData(embedding_matrix=embedding_matrix,embedding_dim=dim, seq_length=s_length, meta_data=meta_data)

embedding_train = get_embedding_data(embedding_matrix, meta_train)
str(embedding_train)
# Out:
# 'EmbeddingData(Embedding length:3578, Embedding dim: 300, seq length: 26, meta length: 2)'

# %% [markdown]
# Define how to build the word-to vector branch:

# %%
def word_2_vec_model(embedding_matrix, num_words, embedding_dim, seq_length, input_tensor):
        # notes:
        # num works: scalar represents size of original corpus
        # embedding_dim : dim reduction. every input string will be encoded in a binary fashion using a vector of this length
        # embedding_matrix (AKA embedding_initializers): represents a pre trained network

        LSTM_UNITS = 512
        DENSE_UNITS = 1024
        DENSE_ACTIVATION = 'relu'


        logger.debug("Creating Embedding model")
        x = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=seq_length,trainable=False)(input_tensor)
        x = LSTM(units=LSTM_UNITS, return_sequences=True, input_shape=(seq_length, embedding_dim))(x)
        x = BatchNormalization()(x)
        x = LSTM(units=LSTM_UNITS, return_sequences=False)(x)
        x = BatchNormalization()(x)
        x = Dense(units=DENSE_UNITS, activation=DENSE_ACTIVATION)(x)
        model = x
        logger.debug("Done Creating Embedding model")
        return model

# %% [markdown]
# In the same manner, define how to build the image representation branch:

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import Dense, GlobalAveragePooling2D#, Input, Dropout
def get_image_model(base_model_weights=DEFAULT_IMAGE_WIEGHTS, out_put_dim=1024):
    base_model_weights = base_model_weights

    # base_model = VGG19(weights=base_model_weights,include_top=False)
    base_model = VGG19(weights=base_model_weights, include_top=False)
    base_model.trainable = False

    x = base_model.output
    # add a global spatial average pooling layer
    x = GlobalAveragePooling2D(name="image_model_average_pool")(x)
    # let's add a fully-connected layer
    x = Dense(out_put_dim, activation='relu',name="image_model_dense")(x)
    # and a logistic layer -- let's say we have 200 classes
    # predictions = Dense(200, activation='softmax')(x)
    model = x
    
    return base_model.input , model

# %% [markdown]
# Before we start, just for making sure, lets clear the session:

# %%
from keras import backend as keras_backend
keras_backend.clear_session()

# %% [markdown]
# And finally, building the model itself:

# %%
import keras.layers as keras_layers
#Available merge strategies:
# keras_layers.multiply, keras_layers.add, keras_layers.concatenate, 
# keras_layers.average, keras_layers.co, keras_layers.dot, keras_layers.maximum
            
merge_strategy = keras_layers.concatenate

# %%
from keras import Model, models, Input, callbacks
from keras.utils import plot_model, to_categorical
from keras.layers import Dense, Embedding, LSTM, BatchNormalization#, GlobalAveragePooling2D, Merge, Flatten

def get_vqa_model(embedding_data=None):        
        embedding_matrix = embedding_data.embedding_matrix
        num_words = embedding_data.num_words
        num_classes = embedding_data.num_classes

        DENSE_UNITS = 1000
        DENSE_ACTIVATION = 'relu'

        OPTIMIZER = 'rmsprop'
        LOSS = 'categorical_crossentropy'
        METRICS = 'accuracy'

        image_model, lstm_model, fc_model = None, None, None
        try:

            lstm_input_tensor = Input(shape=(embedding_dim,), name='embedding_input')

            logger.debug("Getting embedding (lstm model)")
            lstm_model = word_2_vec_model(embedding_matrix=embedding_matrix, num_words=num_words, embedding_dim=embedding_dim,
                                               seq_length=seq_length, input_tensor=lstm_input_tensor)

            logger.debug("Getting image model")
            out_put_dim = lstm_model.shape[-1].value
            image_input_tensor, image_model = get_image_model(out_put_dim=out_put_dim)


            logger.debug("merging final model")
            fc_tensors = merge_strategy(inputs=[image_model, lstm_model])
            fc_tensors = BatchNormalization()(fc_tensors)
            fc_tensors = Dense(units=DENSE_UNITS, activation=DENSE_ACTIVATION)(fc_tensors)
            fc_tensors = BatchNormalization()(fc_tensors)
            fc_tensors = Dense(units=num_classes, activation='softmax')(fc_tensors)

            fc_model = Model(input=[lstm_input_tensor, image_input_tensor], output=fc_tensors)
            fc_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics=[METRICS])
        except Exception as ex:
            logger.error("Got an error while building vqa model:\n{0}".format(ex))
            models = [(image_model, 'image_model'), (lstm_model, 'lstm_model'), (fc_model, 'lstm_model')]
            for m, name in models:
                if m is not None:
                    logger.error("######################### {0} model details: ######################### ".format(name))
                    try:
                        m.summary(print_fn=logger.error)
                    except Exception as ex2:
                        logger.warning("Failed to print summary for {0}:\n{1}".format(name, ex2))
            raise

        return fc_model

model = get_vqa_model(embedding_data=embedding_train)
model
# Out:
# 21:18:51,987 pythonVQA DEBUG ## Getting embedding (lstm model)
# 21:18:51,989 pythonVQA DEBUG ## Creating Embedding model
# 21:18:53,871 pythonVQA DEBUG ## Done Creating Embedding model
# 21:18:53,872 pythonVQA DEBUG ## Getting image model
# 21:18:54,855 pythonVQA DEBUG ## merging final model
# c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\ipykernel_launcher.py:38: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`

# %% [markdown]
# And the summary of our model:

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, None, None, 6 1792        input_3[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, None, None, 6 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, None, None, 6 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, None, None, 1 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, None, None, 1 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, None, None, 2 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, None, None, 2 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, None, None, 2 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, None, None, 2 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, None, None, 5 1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, None, None, 5 2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, None, None, 5 2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, None, None, 5 2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 5 0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, None, None, 5 2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# embedding_input (InputLayer)    (None, 300)          0
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, None, None, 5 2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 26, 300)      1073400     embedding_input[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, None, None, 5 2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  (None, 26, 512)      1665024     embedding_7[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, None, None, 5 2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 26, 512)      2048        lstm_13[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, None, None, 5 0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, 512)          2099200     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# image_model_average_pool (Globa (None, 512)          0           block5_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 512)          2048        lstm_14[0][0]
# __________________________________________________________________________________________________
# image_model_dense (Dense)       (None, 1024)         525312      image_model_average_pool[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         525312      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2048)         0           image_model_dense[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2048)         8192        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1000)         2049000     batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1000)         4000        dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4471)         4475471     batch_normalization_16[0][0]
# ==================================================================================================
# Total params: 32,453,391
# Trainable params: 31,371,847
# Non-trainable params: 1,081,544
# __________________________________________________________________________________________________

# %% [markdown]
# We better save it:

# %%
def print_model_summary_to_file(fn, model):
    # Open the file
    with open(fn,'w') as fh:
        # Pass the file handle in as a lambda function to make it callable
        model.summary(print_fn=lambda x: fh.write(x + '\n'))
        

ts = get_time_stamp()

now_folder = os.path.abspath('{0}\\{1}\\'.format(vqa_models_folder, ts))
model_fn = os.path.join(now_folder, 'vqa_model.h5')
model_image_fn = os.path.join(now_folder, 'model_vqa.png5')
summary_fn = os.path.join(now_folder, 'model_summary.txt')
logger.debug("saving model to: '{0}'".format(model_fn))

try:
    File.validate_dir_exists(now_folder)
    model.save(model_fn)  # creates a HDF5 file 'my_model.h5'
    logger.debug("model saved")
except Exception as ex:
    logger.error("Failed to save model:\n{0}".format(ex))

try:
    logger.debug("Writing history")
    print_model_summary_to_file(summary_fn, model)
    logger.debug("Done Writing History")
    logger.debug("Plotting model")
    plot_model(model, to_file=model_image_fn)
    logger.debug("Done Plotting")
except Exception as ex:
    logger.warning("{0}".format(ex))
# Out:
# 21:11:07,543 pythonVQA DEBUG ## saving model to: 'C:\Users\Public\Documents\Data\2018\vqa_models\20180605_2111_07\vqa_model.h5'
# 21:11:07,870 pythonVQA DEBUG ## model saved
# 21:11:07,871 pythonVQA DEBUG ## Writing history
# 21:11:07,876 pythonVQA DEBUG ## Done Writing History
# 21:11:07,877 pythonVQA DEBUG ## Plotting model
# 21:11:07,886 pythonVQA WARNING ## Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# ### Training the model
