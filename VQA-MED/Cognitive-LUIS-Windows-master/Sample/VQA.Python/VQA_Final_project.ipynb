# %% [markdown]
# # VQA - MED

# %% [markdown]
# This notebook demostraits the efforts made for Visual Q&A based on the data set from VQA-Med 2018 contest

# %% [markdown]
# ## Abstract

# %% [markdown]
# The inputs for VQA are:
# 1. The question text
# 2. The image
#
# The question text is being embedded into a feature vector using a pre-traing [globe file](https://nlp.stanford.edu/projects/glove/).
#
# In a similar manner the image is being processed using a pre trained deep NN (e.g. [VGG](http://qr.ae/TUTEKo) with initial wights of a pretrained [imagenet model](https://en.wikipedia.org/wiki/ImageNet))

# %% [markdown]
# ## The plan

# %% [markdown]
# 0. [Preperations and helpers](#Preperations-and-helpers)
# 1. [Collecting pre processing item](#Collecting-pre-processing-item)
# 2. [Preprocessing and creating meta data](#Preprocessing-and-creating-meta-data)
# 3. [Creating the model](#Creating-the-model)
# 4. [Training the model](#Training-the-model)
# 5. [Testing the model](#Testing-the-model)

# %% [markdown]
# ### Preperations and helpers

# %% [markdown]
# The following are just helpers & utils imports - feel free to skip...

# %%
from parsers.utils import VerboseTimer
from utils.os_utils import File, print_progress

# %% [markdown]
# ### Collecting pre processing item

# %% [markdown]
# ###### Download pre trained items & store their location

# %%
#TODO: Add down loading for glove file

# %%
import os
seq_length =    26
embedding_dim = 300

glove_path =                    os.path.abspath('data/glove.6B.{0}d.txt'.format(embedding_dim))
embedding_matrix_filename =     os.path.abspath('data/ckpts/embeddings_{0}.h5'.format(embedding_dim))
ckpt_model_weights_filename =   os.path.abspath('data/ckpts/model_weights.h5')

# %%
import os
# Fail fast...
suffix = "Failing fast:\n"
assert os.path.isfile(glove_path), suffix+"glove file does not exists:\n{0}".format(glove_path)
# assert os.path.isfile(embedding_matrix_filename), suffix+"Embedding matrix file does not exist:\n{0}".format(embedding_matrix_filename)
assert os.path.isfile(ckpt_model_weights_filename), suffix+"glove file does not exists:\n{0}".format(ckpt_model_weights_filename)

print('Validated file locations')
# Out:
# Validated file locations

# %% [markdown]
# ##### Set locations for pre-training items to-be created

# %%
# Pre process results files
data_prepo_meta            = os.path.abspath('data/my_data_prepro.json')
data_prepo_meta_validation = os.path.abspath('data/my_data_prepro_validation.json')
# Location of embediing pre trained matrix
embedding_matrix_filename  = os.path.abspath('data/ckpts/embeddings_{0}.h5'.format(embedding_dim))

# The location to dump models to
vqa_models_folder          = "C:\\Users\\Public\\Documents\\Data\\2018\\vqa_models"

# %% [markdown]
# ### Preprocessing and creating meta data

# %% [markdown]
# We will use this function for creating meta data:

# %%
from vqa_logger import logger 
import itertools
import string
from utils.os_utils import File #This is a simplehelper file of mine...

def create_meta(meta_file_location, df):
        logger.debug("Creating meta data ('{0}')".format(meta_file_location))
        def get_unique_words(col):
            single_string = " ".join(df[col])
            exclude = set(string.punctuation)
            s_no_panctuation = ''.join(ch for ch in single_string if ch not in exclude)
            unique_words = set(s_no_panctuation.split(" ")).difference({'',' '})
            print("column {0} had {1} unique words".format(col,len(unique_words)))
            return unique_words

        cols = ['question', 'answer']
        unique_words = set(itertools.chain.from_iterable([get_unique_words(col) for col in cols]))
        print("total unique words: {0}".format(len(unique_words)))

        metadata = {}
        metadata['ix_to_word'] = {str(word): int(i) for i, word in enumerate(unique_words)}
        metadata['ix_to_ans'] = {ans:i for ans, i in enumerate(set(df['answer']))}
        # {int(i):str(word) for i, word in enumerate(unique_words)}

        File.dump_json(metadata,meta_file_location)
        return metadata

# %% [markdown]
# And lets create meta data for training & validation sets:

# %%
from collections import namedtuple
dbg_file_csv_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA.csv'
dbg_file_xls_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA_post_pre_process_intermediate.xlsx'#"'C:\\\\Users\\\\avitu\\\\Documents\\\\GitHub\\\\VQA-MED\\\\VQA-MED\\\\Cognitive-LUIS-Windows-master\\\\Sample\\\\VQA.Python\\\\dumped_data\\\\vqa_data.xlsx'
dbg_file_xls_processed_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-QA_post_pre_process.xlsx'
train_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-images\\embbeded_images.hdf'
images_path_train = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Train\\VQAMed2018Train-images'


dbg_file_csv_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA.csv'
dbg_file_xls_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA_post_pre_process_intermediate.xlsx'
dbg_file_xls_processed_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-QA_post_pre_process.xlsx'
validation_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-images\\embbeded_images.hdf'
images_path_validation = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Valid\\VQAMed2018Valid-images'


dbg_file_csv_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA.csv'
dbg_file_xls_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA_post_pre_process_intermediate.xlsx'
dbg_file_xls_processed_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-QA_post_pre_process.xlsx'
test_embedding_path = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-images\\embbeded_images.hdf'
images_path_test = 'C:\\Users\\Public\\Documents\\Data\\2018\\VQAMed2018Test\\VQAMed2018Test-images'

DataLocations = namedtuple('DataLocations', ['data_tag', 'raw_csv', 'raw_xls', 'processed_xls','images_path'])
train_data = DataLocations('train', dbg_file_csv_train,dbg_file_xls_train,dbg_file_xls_processed_train, images_path_train)
validation_data = DataLocations('validation', dbg_file_csv_validation, dbg_file_xls_validation, dbg_file_xls_processed_validation, images_path_validation)
test_data = DataLocations('test', dbg_file_csv_test, dbg_file_xls_test, dbg_file_xls_processed_test, images_path_test)

# %% [markdown]
# Get the data itself, Note the only things required in dataframe are:
# 1. image_name
# 2. question
# 3. answer

# %%
from parsers.VQA18 import Vqa18Base
df_train = Vqa18Base.get_instance(train_data.processed_xls).data            
df_val = Vqa18Base.get_instance(validation_data.processed_xls).data
df_train.head(2)
# Out:
# 20:58:24,378 matplotlib DEBUG ## $HOME=C:\Users\avitu
# 20:58:24,380 matplotlib DEBUG ## matplotlib data path c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\matplotlib\mpl-data
# 20:58:24,386 matplotlib DEBUG ## loaded rc file c:\local\Anaconda3-4.1.1-Windows-x86_64\envs\conda_env\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 20:58:24,388 matplotlib DEBUG ## matplotlib version 2.2.2
# 20:58:24,389 matplotlib DEBUG ## interactive is False
# 20:58:24,390 matplotlib DEBUG ## platform is win32
# 20:58:24,391 matplotlib DEBUG ## loaded modules: ['builtins', 'sys', '_frozen_importlib', '_imp', '_warnings', '_thread', '_weakref', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'zipimport', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_weakrefset', '_bootlocale', '_locale', 'encodings.cp1255', 'site', 'os', 'errno', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'sysconfig', 'types', 'functools', '_functools', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'weakref', 'collections.abc', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'mpl_toolkits', 'google', 'runpy', 'pkgutil', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'ast', '_ast', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'textwrap', 'gettext', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.openpy', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.signatures', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputsplitter', 'IPython.core.inputtransformer', 'IPython ...
#          image_name                      answer  brain  row_id   neck  \
# 0          rjv03401  lesion at tail of pancreas  False       1  False
# 1  AIAN-14-313-g002          in distal pancreas  False       2  False
#
#                                   tokenized_question     ct  \
# 0                                what doe MRI show ?  False
# 1  where doe axial seCTion MRI abdomen show hypoe...  False
#
#          tokenized_answer   mri  tumor  abdomen  liver  \
# 0  tumor at tail pancreas  True   True    False  False
# 1         distal pancreas  True  False     True  False
#
#                                             question  hematoma
# 0                                what does mri show?     False
# 1  where does axial section mri abdomen show hypo...     False

# %%
print("----- Creating training meta -----")
meta_train = create_meta(data_prepo_meta, df_train)

print("\n----- Creating validation meta -----")
meta_validation = create_meta(data_prepo_meta, df_val)

meta_train
# Out:
# 20:59:51,971 pythonVQA DEBUG ## Creating meta data ('C:\Users\avitu\Documents\GitHub\VQA-MED\VQA-MED\Cognitive-LUIS-Windows-master\Sample\VQA.Python\data\my_data_prepro.json')
# 20:59:52,89 pythonVQA DEBUG ## Creating meta data ('C:\Users\avitu\Documents\GitHub\VQA-MED\VQA-MED\Cognitive-LUIS-Windows-master\Sample\VQA.Python\data\my_data_prepro.json')
# ----- Creating training meta -----
# column question had 3317 unique words
# column answer had 3255 unique words
# total unique words: 3578
#
# ----- Creating validation meta -----
# column question had 399 unique words
# column answer had 669 unique words
# total unique words: 881
# {'ix_to_word': {'senile': 0,
#   'peritoneum': 1,
#   'opacities': 2,
#   'calvarial': 3,
#   'alar': 4,
#   'facets': 5,
#   'damage': 6,
#   'subpleural': 7,
#   'lad': 8,
#   'ethmoidal': 9,
#   'intrapulmonary': 10,
#   'bladders': 11,
#   'signals': 12,
#   'aggregates': 13,
#   'sellar': 14,
#   'lymphadenopathy': 15,
#   'renal': 16,
#   'fluidfilled': 17,
#   'atrophied': 18,
#   'plate': 19,
#   'form': 20,
#   'sphenoidal': 21,
#   'costo': 22,
#   'tmuor': 23,
#   'regimen': 24,
#   'contents': 25,
#   'perihepatic': 26,
#   'where': 27,
#   'pathological': 28,
#   'underneath': 29,
#   'eccentric': 30,
#   'sarcoma': 31,
#   'ovary': 32,
#   '6': 33,
#   'arch': 34,
#   'myelitis': 35,
#   'clinically': 36,
#   '35': 37,
#   'periventricular': 38,
#   'shape': 39,
#   'marginal': 40,
#   'detect': 41,
#   'significant': 42,
#   'tip': 43,
#   'initial': 44,
#   'margin': 45,
#   'maxilla': 46,
#   's5': 47,
#   'sclerosing': 48,
#   'pericardial': 49,
#   'membrane': 50,
#   'outgrowth': 51,
#   'wing': 52,
#   'comminution': 53,
#   'spectroscopy': 54,
#   'remote': 55,
#   'anorectal': 56,
#   'pachymeningeal': 57,
#   'homogenous': 58,
#   'lines': 59,
#   'end': 60,
#   'expansive': 61,
#   'cross': 62,
#   'concern': 63,
#   'mark': 64,
#   'sternum': 65,
#   'bands': 66,
#   'auditory': 67,
#   'her': 68,
#   'fmd': 69,
#   'divertion': 70,
#   'relapsed': 71,
#   'top': 72,
#   'arterio': 73,
#   'hernioplasty': 74,
#   'cerebritis': 75,
#   'moiety': 76,
#   'bronchiectasis': 77,
#   'narrows': 78,
#   'subregions': 79,
#   'multi': 80,
#   'pericaecal': 81,
#   'repeated': 82,
#   'oriented': 83,
#   'findings': 84,
#   'sinus': 85,
#   'psedo': 86,
#   'radiata': 87,
#   'cancer': 88,
#   'adipose': 89,
#   'spondylolisthesis': 90,
#   'centripetal': 91,
#   'avascular': 92,
#   'levels': 93,
#   'infratemporal': 94,
#   'fibroadipose': 95,
#   'leakage': 96,
#   'disruption': 97,
#   'intramedullary': 98,
#   'calipers': 99,
#   'gluteal': 100,
#   'diagnostic': 101,
#   'pneumothorax': 102,
#   'pericardium': 103,
#   'adnexa': 104,
#   'couch': 105,
#   'ossicle': 106,
#   'moderately': 107,
#   'sacro': 108,
#   'subject': 109,
#   'nodal': 110,
#   'intraarticular': 111,
#   'lumen': 112,
#   'enlargement': 113,
#   'myelocystocele': 114,
#   'patency': 115,
#   'treatment': 116,
#   'lata': 117,
#   'cycles': 118,
#   'glenoid': 119,
#   'infrahepatic': 120,
#   'contracted': 121,
#   'c4': 122,
#   'procedure': 123,
#   'is': 124,
#   'localization': 125,
#   'fixation': 126,
#   'enterography': 127,
#   'up': 128,
#   'condyle': 129,
#   'lead': 130,
#   'prostate': 131,
#   'fb': 132,
#   'bubble': 133,
#   'done': 134,
#   'chondral': 135,
#   'largest': 136,
#   'splenium': 137,
#   'acoustic': 138,
#   'neural': 139,
#   'specific': 140,
#   'insula': 141,
#   'defined': 142,
#   'visualized': 143,
#   'specially': 144,
#   'relapse': 145,
#   'ECRB': 146,
#   'postoperative': 147,
#   'postoperatively': 148,
#   'subretinal': 149,
#   'bulla': 150,
#   'infection': 151,
#   'ongoing': 152,
#   'Ossification': 153,
#   'clot': 154,
#   'triangle': 155,
#   'ankylosed': 156,
#   'parietaloccipital': 157,
#   'relationship': 158,
#   'petrous': 159,
#   'fluid': 160,
#   'postsecond': 161,
#   'upto': 162,
#   'thorax': 163,
#   'transmural': 164,
#   'myelopathy': 165,
#   'aortography': 166,
#   'segmental': 167,
#   'clear': 168,
#   'peripancreatic': 169,
#   'hepatis': 170,
#   'subocclusive': 171,
#   'terms': 172,
#   'delineated': 173,
#   'vessels': 174,
#   'fibrofatty': 175,
#   'opacification': 176,
#   'old': 177,
#   'isodose': 178,
#   'ossifi': 179,
#   'between': 180,
#   'cholangiopancreaticography': 181,
#   'protruding': 182,
#   'sac': 183,
#   'vermian': 184,
#   'fracture': 185,
#   'beginning': 186,
#   'acetabulum': 187,
#   'deficient': 188,
#   'obstructing': 189,
#   'expansiveness': 190,
#   'coalition': 191,
#   'airspace': 192,
#   'ureter': 193,
#   'developing': 194,
#   'man': 195,
#   'ultra': 196,
#   'preperitoneal': 197,
#   'affecting': 198,
#   'anerusym': 199,
#   'severely': 200,
#   'angiographic': 201,
#   'great': 202,
#   'deeper': 203,
#   'obvious': 204,
#   'nodular': 205,
#   'cholangitis': 206,
#   'prolongation': 207,
#   'c6': 208,
#   'concurrent': 209,
#   'cystoid': 210,
#   'circumscribed': 211,
#   'height': 212,
#   't1wi': 213,
#   'Cerebral': 214,
#   'scanogram': 215,
#   'originating': 216,
#   'proton': 217,
#   'occipito': 218,
#   'hyperintensive': 219,
#   'collapse': 220,
#   'laparoscopic': 221,
#   'weakness': 222,
#   'common': 223,
#   'lung': 224,
#   'highly': 225,
#   'peak': 226,
#   'projection': 227,
#   'compound': 228,
#   'infarcted': 229,
#   'cavitary': 230,
#   'thinning': 231,
#   'activity': 232,
#   'crest': 233,
#   'trial': 234,
#   'femurs': 235,
#   'thecal': 236,
#   'hand': 237,
#   'subarachnoid': 238,
#   'hydatid': 239,
#   'labial': 240,
#   'into': 241,
#   'homogeneous': 242,
#   'ectatic': 243,
#   'psoas': 244,
#   'subcapsular': 245,
#   'several': 246,
#   'spot': 247,
#   'appendiceal': 248,
#   'hypoplastic': 249,
#   'possibility': 250,
#   'points': 251,
#   'dl': 252,
#   'obstructed': 253,
#   'thinned': 254,
#   'scans': 255,
#   'suppression': 256,
#   'smooth': 257,
#   'patent': 258,
#   'which': 259,
#   'continuity': 260,
#   'runs': 261,
#   'exacerbation': 262,
#   'midsagittal': 263,
#   'region': 264,
#   'turbinates': 265,
#   'xmr': 266,
#   'Meningitis': 267,
#   'branch': 268,
#   'emphysematous': 269,
#   'fusiform': 270,
#   'width': 271,
#   'access': 272,
#   'lacrimal': 273,
#   'sublingual': 274,
#   'coccyx': 275,
#   'orbital': 276,
#   'approximate': 277,
#   'ACL': 278,
#   'lobule': 279,
#   'supraclinoid': 280,
#   'image': 281,
#   'l4': 282,
#   'hydroureteronephrosis': 283,
#   'involving': 284,
#   'parapharyngeal': 285,
#   'processed': 286,
#   'silastic': 287,
#   'mucin': 288,
#   't7t8': 289,
#   'glass': 290,
#   'quadrant': 291,
#   'mastoid': 292,
#   'ischemia': 293,
#   'instead': 294,
#   'trileaflet': 295,
#   'pars': 296,
#   'new': 297,
#   'nocardia': 298,
#   'evolution': 299,
#   'few': 300,
#   'clinical': 301,
#   'urethra': 302,
#   'sacralization': 303,
#   'sequestration': 304,
#   'behind': 305,
#   'healed': 306,
#   'surasellar': 307,
#   '67': 308,
#   'blind': 309,
#   'subligamentous': 310,
#   'homogeneously': 311,
#   'Triventricular': 312,
#   'caudal': 313,
#   'objects': 314,
#   'till': 315,
#   'ablation': 316,
#   'only': 317,
#   'centrilobular': 318,
#   'bone': 319,
#   'jejunal': 320,
#   'secondary': 321,
#   'concerning': 322,
#   'tracings': 323,
#   'extraskeletal': 324,
#   'descending': 325,
#   'huge': 326,
#   'bronchiectatic': 327,
#   'prone': 328,
#   'supply': 329,
#   'bile': 330,
#   'postembolization': 331,
#   'intac': 332,
#   'ganglia': 333,
#   'exophytic': 334,
#   'seed': 335,
#   'marked': 336,
#   'focal': 337,
#   'measuring': 338,
#   'knee': 339,
#   'fusion': 340,
#   'azygous': 341,
#   'system': 342,
#   'distention': 343,
#   'alveolitis': 344,
#   'same': 345,
#   'glioma': 346,
#   'reversible': 347,
#   'anastomotic': 348,
#   'adenopathy': 349,
#   'solitus': 350,
#   'fundal': 351,
#   'wedged': 352,
#   'fibro': 353,
#   '18': 354,
#   'actual': 355,
#   'cv': 356,
#   'theaortopulmonary': 357,
#   'flexion': 358,
#   'oxycephaly': 359,
#   'infiltration': 360,
#   'also': 361,
#   'periphery': 362,
#   'alveolar': 363,
#   'intrathoracic': 364,
#   'plain': 365,
#   'aml': 366,
#   'dentate': 367,
#   'thalamic': 368,
#   'limited': 369,
#   'pleural': 370,
#   'apparently': 371,
#   'ecrl': 372,
#   'pollicis': 373,
#   'chain': 374,
#   'foraminal': 375,
#   'calcaneus': 376,
#   'uninvolved': 377,
#   'throat': 378,
#   'interposition': 379,
#   'rv': 380,
#   'numerous': 381,
#   'pointing': 382,
#   'focus': 383,
#   'internal': 384,
#   'during': 385,
#   'dynamic': 386,
#   'measurements': 387,
#   'time': 388,
#   'rim': 389,
#   'lasting': 390,
#   'matrix': 391,
#   'osteopetrosis': 392,
#   'starfield': 393,
#   'pineal': 394,
#   'periarticular': 395,
#   'what': 396,
#   'ilium': 397,
#   'nodes': 398,
#   'shoulder': 399,
#   'recurrence': 400,
#   'reconstruction': 401,
#   'ankle': 402,
#   'toothbrush': 403,
#   'bicornis': 404,
#   'tumoral': 405,
#   'pectoralis': 406,
#   'elbow': 407,
#   'exostosis': 408,
#   'c2t1': 409,
#   'tentorial': 410,
#   'blood': 411,
#   'hypodensity': 412,
#   '29th': 413,
#   'subcutaneous': 414,
#   'cavernosa': 415,
#   'saddle': 416,
#   'growth': 417,
#   'fibroids': 418,
#   'nearly': 419,
#   'ridht': 420,
#   'presentations': 421,
#   'against': 422,
#   'athletic': 423,
#   'technique': 424,
#   'CA': 425,
#   'cerebellopontine': 426,
#   'turbinate': 427,
#   'ventricle': 428,
#   'testis': 429,
#   'development': 430,
#   'sphincter': 431,
#   'pancreas': 432,
#   'eroding': 433,
#   'vrt': 434,
#   'invading': 435,
#   'interpole': 436,
#   't5': 437,
#   'obliterating': 438,
#   'paracardiac': 439,
#   'deformation': 440,
#   'spondylotic': 441,
#   'isodense': 442,
#   'examination': 443,
#   'showsed': 444,
#   'hemorrhage': 445,
#   'Abdominopelvic': 446,
#   'center': 447,
#   'sections': 448,
#   'portion': 449,
#   'side': 450,
#   'minor': 451,
#   'equal': 452,
#   'docetaxel': 453,
#   'varicosities': 454,
#   'polyposis': 455,
#   'patchy': 456,
#   'carcinoma': 457,
#   'global': 458,
#   'valve': 459,
#   'another': 460,
#   'separation': 461,
#   'mandibular': 462,
#   'fibrosis': 463,
#   'osteochondral': 464,
#   'single': 465,
#   '76': 466,
#   'intravitreal': 467,
#   'preserved': 468,
#   'movements': 469,
#   'yes': 470,
#   'unremarkable': 471,
#   'his': 472,
#   'supplying': 473,
#   'veins': 474,
#   'looped': 475,
#   'pneumatized': 476,
#   'straight': 477,
#   'coiled': 478,
#   'syndrome': 479,
#   'sided': 480,
#   'Resonance': 481,
#   'insufficient': 482,
#   'lavallee': 483,
#   'patients': 484,
#   'them': 485,
#   'shoe': 486,
#   'tractography': 487,
#   'humerus': 488,
#   'polyp': 489,
#   'trochanter': 490,
#   'dislocation': 491,
#   'extensiondistraction': 492,
#   '3d': 493,
#   'accumulation': 494,
#   'reaching': 495,
#   'surrounding': 496,
#   'structures': 497,
#   'lymphangiectasia': 498,
#   'nonfluent': 499,
#   'contusions': 500,
#   'abdomen': 501,
#   'projecting': 502,
#   'duct': 503,
#   'costal': 504,
#   'swelling': 505,
#   'occlusions': 506,
#   'adhesions': 507,
#   'watershed': 508,
#   'opll': 509,
#   'nephrogram': 510,
#   'suprasellar': 511,
#   'petroclival': 512,
#   'loss': 513,
#   'restore': 514,
#   'local': 515,
#   'throughout': 516,
#   'incarceration': 517,
#   'concentric': 518,
#   'd12': 519,
#   'hemithorax': 520,
#   'milk': 521,
#   'Area': 522,
#   'longer': 523,
#   'reconstructed': 524,
#   'heterogeneous': 525,
#   'fasciitis': 526,
#   'T2WI': 527,
#   'septa': 528,
#   'neurovascular': 529,
#   'dwi': 530,
#   'coffee': 531,
#   'histopathologic': 532,
#   'cone': 533,
#   'component': 534,
#   'ssfp': 535,
#   'bulbous': 536,
#   'organs': 537,
#   'views': 538,
#   'suprapatellar': 539,
#   'clearer': 540,
#   'mucositis': 541,
#   'chunks': 542,
#   'landmarks': 543,
#   'suspected': 544,
#   'unclear': 545,
#   'coin': 546,
#   'mayo': 547,
#   'mesenteric': 548,
#   'of': 549,
#   'parenchymal': 550,
#   'contraceptive': 551,
#   'oral': 552,
#   'pyometra': 553,
#   'putaminal': 554,
#   'palatinal': 555,
#   'plaques': 556,
#   'vena': 557,
#   'minocycline': 558,
#   'preablation': 559,
#   'configuration': 560,
#   'resorbed': 561,
#   'ascending': 562,
#   'fraction': 563,
#   'ahighly': 564,
#   'thin': 565,
#   'medially': 566,
#   'anteriorly': 567,
#   'papilla': 568,
#   'thickening': 569,
#   'cerebellar': 570,
#   'distortion': 571,
#   'cuboid': 572,
#   'consolidation': 573,
#   'why': 574,
#   'pressing': 575,
#   'T1': 576,
#   'septated': 577,
#   'implantation': 578,
#   'svc': 579,
#   'palliative': 580,
#   'defect': 581,
#   'canal': 582,
#   'persistent': 583,
#   'true': 584,
#   'contoured': 585,
#   'pure': 586,
#   'hypodense': 587,
#   'loculated': 588,
#   'pneumoperitoneum': 589,
#   'yellow': 590,
#   'contrastenhanced': 591,
#   't2wi': 592,
#   'caking': 593,
#   'Coronal': 594,
#   'subsegmental': 595,
#   'carcinoid': 596,
#   'scout': 597,
#   'cisterns': 598,
#   'multifidus': 599,
#   'scapular': 600,
#   'length': 601,
#   'but': 602,
#   'arrowhead': 603,
#   'meets': 604,
#   'deb': 605,
#   'maximus': 606,
#   'retro': 607,
#   'such': 608,
#   'randomly': 609,
#   'set': 610,
#   'diffuse': 611,
#   'uterine': 612,
#   'omentum': 613,
#   'speckled': 614,
#   'retropharyngeal': 615,
#   'being': 616,
#   'successful': 617,
#   'slip': 618,
#   'bronchi': 619,
#   'calculi': 620,
#   'paraspinal': 621,
#   'conduit': 622,
#   'septum': 623,
#   'trabeculation': 624,
#   'prostatic': 625,
#   'foreign': 626,
#   'zygoma': 627,
#   'organized': 628,
#   'striped': 629,
#   'field': 630,
#   'aphasia': 631,
#   'progression': 632,
#   'metopic': 633,
#   'accompanying': 634,
#   'fragments': 635,
#   'thickness': 636,
#   'polar': 637,
#   'parenchyme': 638,
#   'peduncle': 639,
#   'disseminated': 640,
#   'deviation': 641,
#   'representative': 642,
#   'ecrb': 643,
#   'apex': 644,
#   'ich': 645,
#   'arm': 646,
#   'trachea': 647,
#   'myelolipomas': 648,
#   'intestines': 649,
#   'varices': 650,
#   'lymph': 651,
#   'osteolytic': 652,
#   'osteoephysis': 653,
#   'infarctions': 654,
#   'peritonitis': 655,
#   'final': 656,
#   'myocardium': 657,
#   'hip': 658,
#   'temporalis': 659,
#   'bulky': 660,
#   'extraocular': 661,
#   'Type': 662,
#   'lying': 663,
#   'bird': 664,
#   'appearance': 665,
#   'point': 666,
#   'mimicking': 667,
#   'disconnection': 668,
#   'loops': 669,
#   'lumbar': 670,
#   'esophagus': 671,
#   'Reaccumulation': 672,
#   'dilaceration': 673,
#   'corresponding': 674,
#   'reversed': 675,
#   'its': 676,
#   'reformatted': 677,
#   'bulbus': 678,
#   'Ideberg': 679,
#   'aerated': 680,
#   'closely': 681,
#   'blastic': 682,
#   'divisum': 683,
#   'septal': 684,
#   'dripping': 685,
#   'there': 686,
#   'airfluid': 687,
#   'apraxia': 688,
#   'horizontal': 689,
#   'retrogastric': 690,
#   'arteries': 691,
#   'completely': 692,
#   'rectus': 693,
#   'avn': 694,
#   'decreased': 695,
#   'Nasopharyngeal': 696,
#   'caecal': 697,
#   'sellae': 698,
#   'hypoglossal': 699,
#   'ld': 700,
#   'demarcated': 701,
#   'plates': 702,
#   'papillary': 703,
#   'diskitis': 704,
#   'atresia': 705,
#   'combination': 706,
#   'completed': 707,
#   'CT': 708,
#   'display': 709,
#   'way': 710,
#   'ahypodense': 711,
#   'heterologous': 712,
#   'representing': 713,
#   'lining': 714,
#   'repaired': 715,
#   'seeding': 716,
#   'hemicolectomy': 717,
#   'transarterial': 718,
#   'output': 719,
#   'intraventricular': 720,
#   'kissing': 721,
#   't7': 722,
#   'hemispheres': 723,
#   'atrophy': 724,
#   'utero': 725,
#   'radiofrequency': 726,
#   'multiple': 727,
#   'incomplete': 728,
#   'polyhydramnios': 729,
#   'laminar': 730,
#   'symmetrical': 731,
#   'spongy': 732,
#   'muscular': 733,
#   'suggests': 734,
#   'hernia': 735,
#   'angio': 736,
#   'intensely': 737,
#   'fish': 738,
#   'wispy': 739,
#   'benign': 740,
#   'clavicula': 741,
#   'processus': 742,
#   'looked': 743,
#   'rounded': 744,
#   'discharge': 745,
#   'portosystemic': 746,
#   'abscess': 747,
#   'hypointense': 748,
#   'ringenhancing': 749,
#   'pockets': 750,
#   'vesicle': 751,
#   't1w': 752,
#   'inhomogeneously': 753,
#   'pouch': 754,
#   'roots': 755,
#   'penis': 756,
#   'advanced': 757,
#   'filled': 758,
#   'counterpart': 759,
#   'infratentorial': 760,
#   'bladder': 761,
#   'misplaced': 762,
#   'air': 763,
#   'confirming': 764,
#   'strutarising': 765,
#   'wound': 766,
#   'D11': 767,
#   'coil': 768,
#   'classic': 769,
#   'facet': 770,
#   'sublaxation': 771,
#   'process': 772,
#   'cord': 773,
#   'craniovertebral': 774,
#   'bronchus': 775,
#   'decompression': 776,
#   'frontoparietal': 777,
#   'habitual': 778,
#   'orthotopic': 779,
#   'fistulization': 780,
#   'towards': 781,
#   'found': 782,
#   'ulcerative': 783,
#   'megarectum': 784,
#   'pelvi': 785,
#   'VII': 786,
#   'hematometra': 787,
#   '74': 788,
#   'hypothalamus': 789,
#   'revealed': 790,
#   'inflamed': 791,
#   'fibrocartilage': 792,
#   'extraluminal': 793,
#   'Comminuted': 794,
#   'flushing': 795,
#   'gluteus': 796,
#   'depict': 797,
#   'state': 798,
#   'peritumoral': 799,
#   'Suspicion': 800,
#   'solitary': 801,
#   'collateral': 802,
#   'extracapsular': 803,
#   'at': 804,
#   'oblongata': 805,
#   'screw': 806,
#   'recovery': 807,
#   'occlusive': 808,
#   'hypoperfusion': 809,
#   'bi': 810,
#   'dorsi': 811,
#   'many': 812,
#   'confined': 813,
#   'myelum': 814,
#   'implant': 815,
#   'enlarged': 816,
#   'device': 817,
#   'infra': 818,
#   'appearances': 819,
#   'together': 820,
#   'discogram': 821,
#   'extrinsic': 822,
#   'acl': 823,
#   'retrobulbar': 824,
#   'localized': 825,
#   'chronic': 826,
#   'to': 827,
#   'alveolus': 828,
#   'polypoid': 829,
#   'l4l5': 830,
#   'globe': 831,
#   'diaphragmatic': 832,
#   'nonvisualizability': 833,
#   'compromise': 834,
#   'pathologic': 835,
#   'formed': 836,
#   'slices': 837,
#   'sides': 838,
#   'followup': 839,
#   'unenhanced': 840,
#   'masseter': 841,
#   'pseudomyxoma': 842,
#   'opened': 843,
#   'neurofibroma': 844,
#   'nasopharynx': 845,
#   'bones': 846,
#   'clefting': 847,
#   'proximity': 848,
#   'nut': 849,
#   'foci': 850,
#   'tile': 851,
#   'middle': 852,
#   'collection': 853,
#   'What': 854,
#   'cholangiogram': 855,
#   'starry': 856,
#   'later': 857,
#   'haziness': 858,
#   'intravenous': 859,
#   'tomography': 860,
#   'addition': 861,
#   'abnormalities': 862,
#   'next': 863,
#   'teratoma': 864,
#   'nonenhanced': 865,
#   'mostly': 866,
#   'stir': 867,
#   'paravesical': 868,
#   'pore': 869,
#   'modified': 870,
#   'calcaneal': 871,
#   'gauze': 872,
#   'sigmoid': 873,
#   'hypoattenuated': 874,
#   'fascicular': 875,
#   'microlobulated': 876,
#   'infarction': 877,
#   's8': 878,
#   'contiguous': 879,
#   'ugi': 880,
#   'l2': 881,
#   'ischaemic': 882,
#   'migrate': 883,
#   'good': 884,
#   'widening': 885,
#   'ulna': 886,
#   'complex': 887,
#   'tree': 888,
#   'anterolateral': 889,
#   'scimitar': 890,
#   'hepaticojejunostomy': 891,
#   'drainage': 892,
#   'fingerlike': 893,
#   'grade': 894,
#   'nail': 895,
#   'section': 896,
#   'herniation': 897,
#   'takes': 898,
#   'multilobulated': 899,
#   'cholecysto': 900,
#   'intracanalicular': 901,
#   'entire': 902,
#   'scane': 903,
#   'lob': 904,
#   'proliferation': 905,
#   'from': 906,
#   'matter': 907,
#   'spine': 908,
#   'tendinous': 909,
#   'heterointense': 910,
#   'fibrocystic': 911,
#   'segmentation': 912,
#   'effect': 913,
#   'l1': 914,
#   'parotid': 915,
#   'multiforme': 916,
#   'larynx': 917,
#   'hips': 918,
#   'pseudoaneurism': 919,
#   'inferior': 920,
#   'pattern': 921,
#   'presented': 922,
#   'membranes': 923,
#   'sutures': 924,
#   'alignment': 925,
#   'kind': 926,
#   'ill': 927,
#   'l2l3': 928,
#   'orbits': 929,
#   'regular': 930,
#   'SBFS': 931,
#   'devascularization': 932,
#   'retina': 933,
#   't2hyperintense': 934,
#   'C7D2': 935,
#   'wide': 936,
#   'lumbasacral': 937,
#   'densities': 938,
#   'niveau': 939,
#   'hemoperitoneum': 940,
#   'contrastfilled': 941,
#   'gastrohepatic': 942,
#   's4': 943,
#   'vertebral': 944,
#   'back': 945,
#   'epicardial': 946,
#   'reduction': 947,
#   'seemingly': 948,
#   'kyphotic': 949,
#   'ovarian': 950,
#   'dumon': 951,
#   'placement': 952,
#   'preoperative': 953,
#   'sacral': 954,
#   'prevesical': 955,
#   'probably': 956,
#   'avid': 957,
#   'evidence': 958,
#   'lesional': 959,
#   'normal': 960,
#   'broken': 961,
#   'extrauterine': 962,
#   'inlet': 963,
#   'low': 964,
#   'connector': 965,
#   'fistula': 966,
#   'tissue': 967,
#   'embolism': 968,
#   'retained': 969,
#   'longissimus': 970,
#   'directly': 971,
#   'lymphocyst': 972,
#   'margins': 973,
#   'encephalocele': 974,
#   '3rd': 975,
#   'appearing': 976,
#   'infarcts': 977,
#   'discussed': 978,
#   'abductor': 979,
#   'along': 980,
#   'cavernoma': 981,
#   'cardiophrenic': 982,
#   'clavicular': 983,
#   'sinusitis': 984,
#   'deformity': 985,
#   'omental': 986,
#   'cranium': 987,
#   'percutaneous': 988,
#   'coronary': 989,
#   'pectoral': 990,
#   'idiopathic': 991,
#   'bifida': 992,
#   'flattening': 993,
#   'intracardiac': 994,
#   'mineralization': 995,
#   '34mm': 996,
#   'convexity': 997,
#   'neuroma': 998,
#   'sigma': 999,
#   ...},
#  'ix_to_ans': {0: 'hyperintensity on T1-weighted MRI image',
#   1: 'the lesion',
#   2: 'within the pelvis of left kidney',
#   3: 'postoperative sagittal ct spine',
#   4: 'mri thoracolumbar spine',
#   5: 'a retroperitoneal hematoma adherent to the right psoas muscle',
#   6: 'thickening of the aortic wall',
#   7: 'in the right breast',
#   8: 'inflammatory arthritis with the effusion of the knee joint',
#   9: 'axial section of ct scan',
#   10: 'the sphenoid fracture',
#   11: 'involvement of superficial and deeper tissues',
#   12: 'below the knee',
#   13: 'the ct image',
#   14: 'contrast blush in grade ii splenic injury which was later confirmed by surgery perisplenic hemoperitoneum',
#   15: 'trileaflet valve between left atrium and morphological right ventricle',
#   16: 'on the left side with herniation of the right lung',
#   17: 'the magnetic resonance imaging of the heart',
#   18: 'proboscis and polyhydramnios',
#   19: 'contrast media extravasation and bowel loop pooling',
#   20: 'a percutaneous biopsy',
#   21: 'the pancreatic tumor and the left renal oncocytoma',
#   22: 'non contrast head ct of infant',
#   23: 'in pineal region',
#   24: 'significant radiological improvement in terms of clearance of calcifications',
#   25: 'complete hematoma evacuation',
#   26: 'an abdominal catheter entering the urinary bladder',
#   27: 'an echodense right atrial mass concerning for malignancy',
#   28: 'an enhanced abdominal ct',
#   29: 'ct scan of chest with contrast',
#   30: 'intra abdominal free air and perforated viscus',
#   31: 'at the vertebral bodies of t3 and t4',
#   32: 't2 weighted mri sequences',
#   33: 'of posterior pituitary bright spot',
#   34: 'regional lymph node involvement',
#   35: 'both side of the asdh in the supratentorium',
#   36: 'the typical internal or capsular calcification in the spt',
#   37: 'axial t2 weighted thoracolomber mri',
#   38: 'concentric wall thickening of the innominate, left common carotid and both subclavian arteries',
#   39: 'sagittal figure contrast enhanced ct brain',
#   40: 'in the center of the lung mass',
#   41: 'dilatation of the stomach',
#   42: 'at the right site of the neck',
#   43: 'heterogeneously enhancing lobulated mass lesion involving the diaphragmatic pleura',
#   44: 'a cerebellum metastasis',
#   45: 'coronal magnetic resonance imaging image',
#   46: 'hydrocephalus and dilation of ventricles',
#   47: 'multiple calcified nodules',
#   48: 'on the thumb',
#   49: 'lesion in the left maxillary sinus with nasal septum deviation',
#   50: 'axial ct of upper chest',
#   51: 'of small bowel loops with several air fluid levels',
#   52: 'ct of the thigh',
#   53: 'the olfactory fossae are very deep keros type iii',
#   54: 'in the left renal fossa',
#   55: 'in the white matter of both hemispheres',
#   56: 'contrast enhanced abdominal and pelvic ct scan',
#   57: 'high signal of the right basal ganglia and corona radiata indicating acute ischemic infarction',
#   58: 'periesophageal fluid collection in the lower esophagus, along with air collection',
#   59: 'of the anterior and posterior subregions of insula',
#   60: 'coronal and axial ct images',
#   61: 'multiple osteolytic lesions with contrast enhancement and central necrosis',
#   62: 'three dimensional ct scanning in different views',
#   63: 'a hepatic mass',
#   64: 'embolism inthe pulmonary arteries and their branches',
#   65: 'acute left pons infarct',
#   66: 'of a smaller soft tissue mass',
#   67: 'multiple liver abscesses',
#   68: 'hypo dense masses',
#   69: 'an ex vivo human lung',
#   70: 'the t2 weighted image',
#   71: 'large heterogenous mass in left lower lung field with necrosis and calcification',
#   72: 'the lateral ventricles',
#   73: 'an absence of the left unilateral lumbar facet joint and hyoplasia of the lamina',
#   74: 'axial ct scan of the paranasal sinus with contrast',
#   75: 'bronchiectasis',
#   76: 'a heterogeneous increased signal',
#   77: 'hypodens lesion with same surrounding hyperdensity at coracoglenoid junction',
#   78: 'homogenous intensity of the accessory center',
#   79: 'few small cortical contusions',
#   80: 'part of the bowel and omentum in the chest',
#   81: 'in the region anterior to the sacrum',
#   82: 'a right coronary artery',
#   83: 'of high intensity in t2 weighted mri images',
#   84: 'a hepatic mass on the right lobe with hyperattenuating components suggesting acute bleeding',
#   85: 'ct scan with contrast of the chest',
#   86: 'the abscess in the caudate lobe of the liver',
#   87: 'axial reformatted ct scan of cervical spine',
#   88: 'enlarged left and right adrenals',
#   89: 'the area of hemorrhage',
#   90: 'axial contrast enhanced ct scans',
#   91: 'a nonocclusive thrombus within the main portal vein',
#   92: 'a hyper-intense lesion with a hypo-intense rim',
#   93: 'pancreatic calcifications and mass',
#   94: 'diffuse and asymmetrical thickening of the vesical wall',
#   95: 'a massive epidural hemorrhage from c2 to l1 level',
#   96: 'in liver',
#   97: 'head ct and mri',
#   98: 'edema and high signal intensity in the region of the left multifidus and longissimus muscles',
#   99: 'ct scan of the pelvis',
#   100: 'of the vertebrobasilar artery and the internal carotid arteries',
#   101: 'a splenic abscess',
#   102: 'to the vena cava',
#   103: 'the abnormal location of an infarcted spleen within the pelvis',
#   104: 'the foraminal leak',
#   105: 'in the upper lobe of the right lung',
#   106: 'over l5 s1 level',
#   107: 'axial section of ct angiogram',
#   108: 'axial ct image through the upper pole of right kidney',
#   109: 'diffusion mri brain without contrast',
#   110: 'renal hypoperfusion',
#   111: 'a large density around the duodenum',
#   112: 'normal brachial plexus on both sides',
#   113: 'nonspecific fat deposition in the rv free wall',
#   114: 'a dense nidus of central calcification in an adenocarcinoma of the lung',
#   115: 'ct with 3d reconstruction view',
#   116: 'the cp angle lesion which was hypointense on t1w and hyperintense on t2w image',
#   117: 'in the scrotum',
#   118: 'in nodules',
#   119: 'a signal void brain lesion in the left trigone area',
#   120: 'an initial downsizing of the lesion',
#   121: 'in anterior abdominal wall',
#   122: 'multifocal inflammatory colonic wall thickening on the ascending colon',
#   123: 'extensive marrow oedema of the left pubic ramus',
#   124: 'in the thoracic spinal cord',
#   125: 'in the right mandible',
#   126: 'of pulmonary artery pseudoaneurysm post procedure',
#   127: 'extension to the left mastoid and frontal bone',
#   128: 'the red mark',
#   129: 'an intradural hematoma',
#   130: 'enhanced magnetic resonance imaging of the right lower leg',
#   131: 'the proximal insertion of the mcl',
#   132: 'in the left pulmonary artery',
#   133: 'the shunt tube',
#   134: 'clefting of the anterior arch of the atlas and dysplasia of the posterior arch',
#   135: 'the occipital cyst with an eccentric nodule representing scolex',
#   136: 'ectopic varices at parastomal site',
#   137: 'the typical findings in resuscitation related brain injury',
#   138: 'a well circumscribed and septated lesion in the left side of the midline neck',
#   139: 'multiple sinuses extending till the underlying muscles',
#   140: 'a large right csh',
#   141: 'the variceal vessels',
#   142: 'contrast enhanced t1w saggital mri',
#   143: 'mural thickening in the ascending colon',
#   144: 'another mass in the region anterior to the sacrum',
#   145: 'contrast enhanced ct scan of the upper thorax',
#   146: 'in the left axilla',
#   147: 'of the tumor',
#   148: 'fixation',
#   149: 'loops of bowel herniating through the disrupted left hemidiaphragm',
#   150: 'atypical presentations of neurobeh et disease',
#   151: 'anterior and posterior parallel thick lines of avid enhancement corresponding to the leptomeninges',
#   152: 'outside the dose grid region',
#   153: 'multiple cavitary and non cavitary lung nodules, suspicious for mycobacterial infection',
#   154: 'of the pulmonary trunk and the left pulmonary artery',
#   155: 'due to hepatic necrosis',
#   156: 'the cystic part',
#   157: 'in left parieto occipital area',
#   158: 'a chest ct',
#   159: 'preoperative t1 axial mri with contrast',
#   160: 'axial contrast enhanced ct and a pulmonary angiogram',
#   161: 'of talar avn',
#   162: 'superiorly upto bare area of liver',
#   163: 'a narrow sacral canal',
#   164: 'right frontal lobe lesion with inhomogeneous enhancement',
#   165: 'an axial ct image',
#   166: 'a large mass surrounding the heart',
#   167: 'closed olecranon fracture classified as mayo type iiib fracture',
#   168: 'extensive soft tissue destruction',
#   169: 'axial and coronal magnetic resonance images with contrast',
#   170: 'reparation of the lesion of the proximal insertion of the mcl',
#   171: 'mesenteric fat invagination in the right lower quadrant',
#   172: 'a homogeneously enhanced tumor',
#   173: 'a haemangioma located in the femoral inter condylar notch',
#   174: 'calculi in gallbladder',
#   175: 'splenic hypointense homogenous lesion',
#   176: 'in the liver',
#   177: 'cross sectional abdominal mri',
#   178: 'ct angiogram',
#   179: 'in left masticator space',
#   180: 'into the right chest and mediastinum',
#   181: 'axial ct through the mediastinum',
#   182: 'ct scan of the chest',
#   183: 'a bone defect located in the right posterior parietal region with skin bulging',
#   184: 'Ossification',
#   185: 'multiple cysticerci involving both orbits with proptosis',
#   186: 'the toothbrush spanning the nasopharynx and oropharynx, as well as subcutaneous emphysema in the anterior and lateral cervical regions',
#   187: 'a sagittal view of impacted maxillary canine with severe dilaceration',
#   188: 't2 weighted images',
#   189: 'sagittal abdominal ct image',
#   190: 'extensive edema of the left lateral pterygoid muscle in the left infratemporal fossa',
#   191: 'a sinus tract from the proximal femur',
#   192: 'vertebral duplication and myelocystocoele',
#   193: 'massive intercostal aneurysm with thrombus and mild pleural effusion',
#   194: 'at the left iliac bone and at the left sacral wing',
#   195: 'left lamellar concha',
#   196: 'in the right and left acetabulum',
#   197: 'coronal stir mri',
#   198: 'chest spiral ct angiography of the first patient',
#   199: 'axial contrast enhanced ct image through the abdomen',
#   200: 'coronal and axial views of the intraspinal and extraspinal soft tissue mass at t2 t3',
#   201: 'expansion of buccal and lingual cortical plates',
#   202: 'magnetic resonance imaging scan of the pelvis',
#   203: 'the increased signal intensity of subchondral marrow, and the obliteration of joint space in both sacroiliac joints',
#   204: 'the skull arrows',
#   205: 'in both temporal lobes',
#   206: 'of the extraocular portion of the left optic nerve along with great edema',
#   207: 'magnetic resonance spectroscopy of the lesion',
#   208: 'eradication of the varices from the descending colon',
#   209: 'in the posteromedial aspect of the knee and calf',
#   210: 'pelvic magnetic resonance imaging',
#   211: 'ct of kidneys',
#   212: 'of the kidney',
#   213: 'single large cavitary lesion in lower right lobe with satellite nodules',
#   214: 'a right lung tumor',
#   215: 'microscopic ct image of the osteosponge',
#   216: 'of a soft tissue mass arising within the muscles of the right cheek',
#   217: 'primary tumor of left kidney',
#   218: 'of low attenuation in right lobe of liver',
#   219: 'of the ascending aorta',
#   220: 'the lower peritoneal cavity',
#   221: 'calcifications in both breasts and minimal pericardial effusion',
#   222: 'complete resection of anterior osteophytes',
#   223: 'axial t1 weighted mri with gadolinium enhancement',
#   224: 'intratumoral bleeding',
#   225: 'brain magnetic resonance imaging',
#   226: 'a solid right lower pole mass',
#   227: 'from the neural tissue',
#   228: 'the widen vestibular aqueduct',
#   229: 'a large mass in relation to the pancreatic tail',
#   230: 'coronal ct scan of the orbits',
#   231: 'the presence of isodense non enhancing mass in the mandible',
#   232: 'ct and portography through ivc',
#   233: 'vessels',
#   234: 'into the urinary bladder',
#   235: 'scattered areas of t2 hyper intense signal within the white matter of the right cerebral hemisphere in the watershed areas',
#   236: 'in the right lobe of the liver',
#   237: 'a cystic lesion in the region of tail of pancreas suggestive of pancreatic pseudocyst',
#   238: 'coronal t2 weighted mri',
#   239: 'a rim enhancing fluid collection with small bubbles of air anteriorly',
#   240: 'of the superiormesenteric vein',
#   241: 'enlarged lymph nodes involving the right axillary',
#   242: 'lingular tonsillar involvement',
#   243: 'the temporal bone',
#   244: 'enlargement of the bilateral intraocular rectus',
#   245: 'of the goiter with the trachea and the mediastinum',
#   246: 'a left epidural mass',
#   247: 'of the sphenoid sinus',
#   248: 'multiple remnant subsegmental atelectasis',
#   249: 'a heterogenously enhancing well defined mass in the left parietal lobe with surrounding edema',
#   250: ' towards the head of the pancreas',
#   251: 'the c2 c3 and c3 c4 intervertebral discs',
#   252: 'cemento ossifying fibroma',
#   253: 'bilateral calcification in basal ganglia, periventricular demyelination and mild dilatation of lateral ventricles',
#   254: 'the ct',
#   255: 'straightening of the interventricular septum',
#   256: 'on the left uterine cornual portion',
#   257: 't2 weighted brain magnetic resonance imaging',
#   258: 'ct reconstruction picture',
#   259: 'in right parieto temporal white matter',
#   260: 'a mass between stomach and kidney',
#   261: 't2 axial mri imaging',
#   262: 'in the region of left lobe of thyroid',
#   263: 'coronal mri t2 flair sequence',
#   264: 'a mass surrounding suprapubic',
#   265: 'splaying of carotid vessels',
#   266: 'typical presentation of nbd',
#   267: 'an enhancing paraspinal mass with foraminal extension',
#   268: 'a right csh and a contralateral hemispheric hygroma',
#   269: 'the aorta and inferior vena cava',
#   270: 'multiple septated cystic lesion',
#   271: 'hypointensity and fragmentation of the accessory center',
#   272: 'a ct scan',
#   273: 'dilated small bowel loops and concentric thickening of caecal wall close to the ileocaecal junction',
#   274: 'There is increased signal in the spinal cord and lumbosacral roots on sagittal view',
#   275: 'multiple pulmonary arterio venous malformations',
#   276: 'a serpiginous subcutaneous mass in the right temporal occipital region',
#   277: 'left putaminal hemorrhage',
#   278: 'mri t2 coronal and transversal sequences',
#   279: 'in both lobes of the liver',
#   280: 'posterior gastric diverticulum with air and contrast',
#   281: 'ambiguous lesions with high signal intensity in the area of cortical thinning',
#   282: 'irregular dilatation of common bile',
#   283: 'the bullet to be lodged postero medially to the left kidney',
#   284: 'obstructive hydrocephalus and ventriculitis',
#   285: 'luminal narrowing',
#   286: 'the catheter tip in the right upper lobe of the lung and a large dorsobasal pleural effusion',
#   287: 'multiple demyelinating plaques',
#   288: 'in the left hemithorax',
#   289: 'lung',
#   290: 'a large gastric mass',
#   291: 'small calcified nodules with subpleural distribution and subpleural linear calcifications',
#   292: 'subcutaneous emphysema, bilateral pneumothorax, tension pneumopericardium and compressed heart',
#   293: 'an extent of mass',
#   294: 'sagittal ct image with corresponding line diagram',
#   295: 'The hepatic hemangioma has an atypical T2 signal intensity',
#   296: 'axial t2 weighted brain mri',
#   297: 'planning axial ct image',
#   298: 'partial reduction of a metastatic mass in the bilateral internal auditory canals',
#   299: 'bilateral symmetric hyperintense lesions in parieto occipital parenchyma',
#   300: 'ct scan of the chest and neck',
#   301: 'axial mri imaging of the craniocervical junction',
#   302: 'ct findings of the pelvis ct',
#   303: 'a chest ct scan',
#   304: 'mri of left shoulder',
#   305: 'sagittal magnetic resonance image of the cervical spine',
#   306: 'a septic ovarian cyst',
#   307: 'thrombus in the left pulmonary artery',
#   308: 'swelling',
#   309: 'preoperative mri brain contrast t1w images',
#   310: 'smooth lobulated intensely enhancing mass lesion along the superior and lateral aspects of the right orbit',
#   311: 'decompression of ventricles with presence of cm1',
#   312: 'a nodule in the right adrenal gland',
#   313: 'in the left lobe of the liver',
#   314: 'axial magnetic resonance angiography of the brain',
#   315: 'a ct scan of the abdomen and pelvis',
#   316: 'a mass in the medullary canal',
#   317: 'the lesion that corresponds to the area of increased pet uptake',
#   318: 'a fibro-cartilage coalition',
#   319: 'retropharyngeal air and extensive subcutaneous emphysema in neck',
#   320: 'at different levels in the mediastinum',
#   321: 'further ct scan of the abdomen',
#   322: 'a large soft tissue mass in the right middle ear and infratemporal fossa',
#   323: 'ct scan axial section',
#   324: 'enhanced ct',
#   325: 'air space consolidation in left lower lobe',
#   326: 'in the inferior vena cava',
#   327: 'maxillary alveolus',
#   328: 'a well circumscribed lesion with homogenous fat attenuation in the upper lobe of the right lung',
#   329: 'tumor invasion to the SMA or CA',
#   330: 'magnetic resonance imaging of the orbits',
#   331: 'further image of the same ct scan',
#   332: 'an irregular oval-shaped mass, 3 cm in diameter, arising from the right tongue base',
#   333: 'the two layered structure of a thin, compacted epicardial layer and an extremely thick endocardial layer with prominent trabeculations and deep recesses',
#   334: 'oblique coronal reformation image of ct scan',
#   335: 'in mediastinum',
#   336: 'new process developed in the cns',
#   337: 'as evidence for long lasting chronic osteomyelitis',
#   338: 'in the proximal tibia',
#   339: 'a large radiolucent mass in the right medial thigh',
#   340: 'medial meniscus',
#   341: 't2 weighted coronal mri image of the lower extremities',
#   342: 'preoperatively ct and sagittal mri',
#   343: 'a tumorous lesion of the median nerve with a fascicular pattern',
#   344: 'ct urogram',
#   345: 'in the pelvis',
#   346: 'immediate post operative contrast mri',
#   347: 'bone erosion',
#   348: 'emergency abdominal ct',
#   349: 'in the cerebellum',
#   350: 'crescent-shaped fibrotic tissue in theposterior region of the left bulbus oculi',
#   351: 'ct scan of the anterior abdominal wall',
#   352: 'of the aneurysm and its relation to the neighboring structures',
#   353: 'corpus callosum lipoma with intraventricular extension',
#   354: 'a clinoidal meningioma',
#   355: 'arrows in the ct abdomen',
#   356: 'left thyroid mass',
#   357: 'with an association of brainstem and midbrain hypersignal lesions',
#   358: 'sagittal section of ct',
#   359: 'significant tumor reduction',
#   360: 'in the right 7th rib posteriorly on planar and spect imagesand on axial ct slice',
#   361: 'the 12th thoracic vertebra and the pedicle of the 4th lumbar vertebral arch with an abnormal signal',
#   362: 'within the liver',
#   363: 'the abdomen and pelvis coronal section',
#   364: 't1 weighted magnetic resonance imaging section through the brain',
#   365: 'in the occipital and temporal lobes',
#   366: 'dextrocardia with situs solitus',
#   367: 'the uncinate process of the pancreas extended and fused to the dorsal surface of the pancreas body',
#   368: 'of the left cavernous sinus with some defects',
#   369: 'type ii optic nerve',
#   370: 'the disc behind the body of c6 vertebra seen as isointense signal density',
#   371: 'the effusion',
#   372: 'hyperintense signal and enlargement of the left optic nerve',
#   373: 'narrowing of the oropharynx due the membrane',
#   374: 'oblique coronal plane magnetic resonance imaging',
#   375: 'bony expansion',
#   376: 'the skull based plasmacytoma growing through the skull and into actual brain tissue',
#   377: 'a sigmoid colon wall infiltration with surrounding air bubbles',
#   378: 'a thin, compacted epicardial layer and an extremely thick endocardial layer with prominent trabeculations and deep recesses',
#   379: 'an heterologous cranioplasty',
#   380: 'axial contrast enhanced ct image',
#   381: 'the common hepatic artery arising from the superior mesenteric artery',
#   382: 'of the lesion located at the right frontal lobe',
#   383: 'the occluded carotid artery',
#   384: 'large saddle thrombus in main pulmonary artery and deep vein thrombus of external iliac vein',
#   385: 'ct skull',
#   386: 'ileus in the sac at the left side of the ascending colon and dilatation of the oral side of the intestine',
#   387: 'the right hip and reconstruction in coronary view',
#   388: 'sagittal 3dct scan of the spine',
#   389: 'ct scan of abdomen',
#   390: 'nocardia',
#   391: 'diffuse cerebral cortex, brain stem and cerebellar atrophy',
#   392: 'pre operative ct scan',
#   393: 'herniated in the lower right anterior mediastinum',
#   394: 'agenetic sacrum with an anterior meningocele',
#   395: 'vena cava inferior thrombosis with venous collaterals',
#   396: 'axial t2w mri of the brain',
#   397: 'mri of brain',
#   398: 'an extension of the mass into the skull base and the floor of the middle cranial fosse in the extra axial space',
#   399: 'ct image of the cerebrum',
#   400: 'plain ct',
#   401: 'left transverse and lateral sinus',
#   402: 'no significant lesion',
#   403: 'the syrinx',
#   404: 'mri brain sagittal section',
#   405: 'starry sky sign of disseminated neurocysticercosis',
#   406: 'in the occipital region',
#   407: ' Axial contrast-enhanced CT scan',
#   408: 'the jejunal varices',
#   409: 'parathyroid adenoma',
#   410: 'ct angiography via the venous approach',
#   411: 'large ischaemic infarct in the right parietal lobe',
#   412: 'of increased uptake in the left paravertebral area',
#   413: 'ct guided biopsy of adrenal lesions',
#   414: 'between stomach and kidney',
#   415: 'an intense enhancible paraventricular mass',
#   416: '3d reconstructed ct image',
#   417: 'extravasation of oral contrast',
#   418: 'ct scan of the neck before starting belinostat therapy',
#   419: 'axial ct section with contrast media',
#   420: 'localized fluid collection suggestive of abscess in right iliac fossa',
#   421: 't1w axial mri image at the level of the lateral ventricles',
#   422: 'expanded clivus with ground glass density',
#   423: 'the portal vein',
#   424: 'pneumomediastinum, pneumopericardium and surgical emphysema',
#   425: 'heterogeneous lesion in the head and uncinate process of pancreas with non enhancing areas suggestive of necrosis and distended gall bladder',
#   426: 'post operative ct scan',
#   427: 'into three equal portions',
#   428: 'axial ct section of larynx',
#   429: 'a calcified t7 t8 disc compressing on the spinal cord',
#   430: 'preoperative sagittal magnetic resonance image of the ridht knee',
#   431: 'of hemoperitoneum and a perisplenic hematoma',
#   432: 'islands of increased sclerosis in areas of relative radiolucencies within the vertebral bodies',
#   433: 'ileoanal pouch',
#   434: 'the site of the tumor in the left tibia',
#   435: 'in the right flank',
#   436: 'an anterior mediastinal mass',
#   437: 'a round-like signal, in the upper portion of IVS, anterior to the right coronary sinus of aorta',
#   438: 'ct scout film',
#   439: 'magnetic resonance imaging axial scan',
#   440: 'subependymal hamartomas seen along the lateral surface of the lateral ventricles',
#   441: 'coronal section on ct abdomen',
#   442: 'total left hemisphere encephalomalasia',
#   443: 'bone window axial ct images and coronal section of mri',
#   444: 'solitary intensely enhancing microlobulated lesion in the right breast',
#   445: 'Scattered micronodules',
#   446: 'progression of disease after first line palliative chemotherapy with the CAP regimen',
#   447: 'coronal t2 weighted magnetic resonance image',
#   448: 'contrast enhanced ct image',
#   449: 'a large intra abdominal portion communicating through the inguinal canal with an external portion in the groin',
#   450: 'the oblique trajectory and the approach to axis',
#   451: 'a low attenuation endobronchial mass obstructing the anterior bronchus of the right lower lob',
#   452: 'cystic degeneration',
#   453: 'bilateral pleural effusions',
#   454: 'contrast enhanced t1w coronal mri',
#   455: 'of the sphenoid sinuses',
#   456: 'a normal hepatobiliary tree',
#   457: 'blood supply to the brain',
#   458: 'hyperintense signal that involves the muscles of both thighs',
#   459: 'dilated small bowel with a transition point 10 cm from the ileocaecal valve',
#   460: 'discontinuity of the left pars interarticularis and an incidental spina bifida occulta',
#   461: 'the left diaphragm',
#   462: 'mri findings and a t2 weight image',
#   463: 'the tail of the appendix communicating with the appendiceal abscess',
#   464: 'the diverticulum extending towards the head of the pancreas',
#   465: 'recurrence of lesion',
#   466: 'ct slice',
#   467: 'around the medial end of the right clavicle',
#   468: 'recurrence of anterior mediastinal mass extenting into right side of chest',
#   469: 't2 weighted sagittal magnetic resonance images',
#   470: 'diffuse, concentric wall thickening of multiple small bowel loops ',
#   471: 'high resolution ct scan at level of upper lobes',
#   472: 'bilateral psoas and perinephric abscesses',
#   473: 'that there is an anomalous origin of the left coronary artery arising from the right sinus of valsalva',
#   474: 'the white matter abnormality in the occipital lobes',
#   475: 'the posterior aspect of the thoracic thecal sac',
#   476: 'Axial CT scan of the brain',
#   477: 'no recurrence of the tumor',
#   478: 'in the left trigone area',
#   479: 'nodular liver',
#   480: 'gadolinium enhanced t1 weighted image of the same patient',
#   481: 'only modest malalignment and the naked facet sign',
#   482: 'on the pet',
#   483: 't2 weighted magnetic resonance scan image after two months',
#   484: 'the edematous wall of the intussusception and an enhanced homogeneous mass',
#   485: 'without evident contrast extravasation',
#   486: 'the ct scan of head and neck region',
#   487: 'mri brain t1w sagittal image',
#   488: 'in the left maxillary sinus',
#   489: 'in a megarectum',
#   490: 'resolution of pulmonary artery pseudoaneurysm post procedure',
#   491: 'no renal tract calcification',
#   492: 'the renal mass and the thrombus',
#   493: 'multiple pancreatic calculi, splenic vein obstruction, and perigastric and subphrenic dilated collateral veins',
#   494: 'the t2 weighted magnetic resonance imaging of the cervical spine in the sagittal section',
#   495: 'axial ct angiographic image',
#   496: 'in the right lateral-upper quadrant',
#   497: 'agenesis of pectoral muscle in right hemithorax',
#   498: 'progressive and bilateral narrowing of the optic canal',
#   499: 'psedo aneurysm formation',
#   500: 'a large heterogeneous right renal mass',
#   501: 'magnetic resonance imaging of the right wrist in the fluid sensitive inversion recovery sequence',
#   502: 'Sagittal and axial T2-weighted MRI image of atlantoaxial chordoma',
#   503: 'a large retroperitoneal hematoma',
#   504: 'of the supraspinatus tendon attachment',
#   505: 'a pelvic kidney with a normal nephrogram and the surrounding fatty tissue',
#   506: 'the dorsal surface of the pancreas body by surrounding the portal vein',
#   507: 'evidence of pneumoperitoneum',
#   508: 'coronal t2 weighted magnetic resonance image of the facial area',
#   509: 'mri cervical spine',
#   510: 'ct of the brain with orbital section',
#   511: 'bony fragments',
#   512: 'The tumor',
#   513: 'an anomalous origin of the left coronary artery arising from the right sinus of valsalva',
#   514: 'abnormal bone in the lateral femoral condyle and the adjacent tibial plateau',
#   515: 'soft tissue mass with uninvolved mastoid bone',
#   516: 'right lung consolidation with enlarged mediastinal lymph nodes',
#   517: 'a well-circumscribed multi-septated cystic renal mass',
#   518: 'a unilocular, well-defined and high signal intensity cystic lesion with hypointense rim',
#   519: 'the trial femoral head to be inside the iliac muscle of the quadrilateral space within the pelvis',
#   520: 'a well defined cystic lesion along the traversing left l4 nerve root suggestive of perineural cyst',
#   521: 'transversal ct image of the l4 vertebral body,',
#   522: 'prostatic mass',
#   523: 'a large mass',
#   524: 'in the left occipital lobe',
#   525: 'axial section ct pulmonary angiogram',
#   526: 'blood',
#   527: 'resection of the tumor adjacent to the pituitary stalk',
#   528: 'within the right mastoid air cells',
#   529: 'a large pituitary adenoma responsible for visual loss in both eyes',
#   530: 'Initial contrast-enhanced axial CT scan',
#   531: 'lobulated extra-axial hyperdense lesions anterolateral to the lower brainstem',
#   532: 'mild prominence of both the lateral ventricles',
#   533: 'preoperative axial ct of the left knee',
#   534: 'a subarachnoid hemorrhage on the anterior portion of the basal cistern',
# ...
#   718: 'the trial femoral head in the quadrilateral space in the posterior inner wall of the right pelvis',
#   719: 'a high density defect in the distal common bile duct',
#   720: 'exacerbation of the peripancreatic fluid collection and abscess',
#   721: 'left temporal lobe glioblastome multiforme',
#   722: 'ct of the abdomen prior to drain removal',
#   723: 'sagittal t2 weighted mri of woman',
#   724: 'a huge bilateral sinonasal mass',
#   725: 'bronchiectatic cavity of old tuberculosis which grew nocardia',
#   726: 'ileo colic intussusception',
#   727: 'in the vascular territory of right anterior cerebral artery',
#   728: 'actual bleeding',
#   729: 'multiple infarctions within the cerebellar hemispheres',
#   730: 'posterior arch rachischisis',
#   731: 'as areas',
#   732: 'swelling arising from tendon insertion',
#   733: 'that a lesion containing bone like tissues occupied almost the entire maxillary sinus',
#   734: 'the perirenal fat and of the perirenal fascia taking the appearance of hairy kidneys',
#   735: 'bilateral renal infarcts that are predominant on the right side',
#   736: 'neck ct',
#   737: 'ct of cervical region',
#   738: 'after operation',
#   739: 'non enhancing lesion in the tail of pancreas',
#   740: 'mri at age 35',
#   741: 'medial extrusion of posterior calcaneal facet',
#   742: 'medial meniscus cartilage',
#   743: 'the oropharynx laterally',
#   744: 'both healing of the liver laceration and resolution of the intra hepatic infection',
#   745: 'an expansile, osteolytic lesion, with gross expansion of both cortical plates',
#   746: 'extraperitoneal air from the sigmoid perforation diffusing superiorly through paravertebral retroperitoneal tissue and via the diaphragmatic hiatus into the mediastinum',
#   747: 'magnetic resonance imaging axial t2 of right orbit',
#   748: 'aerated part of left lung',
#   749: 'intraretinal cysts but no subretinal fluid',
#   750: 'of the spleen',
#   751: 'rim enhancement of the occipital cyst with an eccentric nodule representing scolex',
#   752: 'multislice ct',
#   753: 'ct scan of the cervical spine',
#   754: 'the magnetic resonance angiogram',
#   755: 'without signs of extrabronchial infiltration',
#   756: 'enlarged basal cisterns and fourth ventricle',
#   757: 'ectactic basilar artery compressing left 5th nerve',
#   758: 'in close proximity to the popliteal vessels',
#   759: 'pneumoperitoneum',
#   760: 'without perforation or abscess formation',
#   761: 't2 weighted magnetic resonance imaging of patient 1',
#   762: 'in both lung fields',
#   763: 'magnetic resonance angiogram of the abdomen',
#   764: 'a coronal ct image of a 70 year old rider',
#   765: 'upper gastrointestinal examination and ct',
#   766: 'a high signal intensity in the lunate',
#   767: 'the presence of dorsal pancreatic duct and ventral pancreatic duct that drains into the major papilla',
#   768: 'of the lesions',
#   769: 'CT scan brain with contrast',
#   770: 'diffuse edematous changes in the superficial and deep fascia of the left leg',
#   771: 'in the left temporal lobe',
#   772: 'of the pylorus and antrum',
#   773: 'focal defect in inflamed appendiceal wall and periappendiceal inflammatory stranding',
#   774: 'cavernous sinus',
#   775: 'this axial ct scan image',
#   776: 'an enhanced lesion of the left hard palate with thickening of the genal mucosa and no bone involvement',
#   777: 'a posterior hyperintense lesion at the cranio cervical junction involving the caudal medulla and the upper cervical cord',
#   778: 'pectoral muscle in right hemithorax',
#   779: 'of the lesion and postoperative changes',
#   780: 'the needle positioned at the lip of the right l5 s1 facet joint',
#   781: 'ct scan image at the level of tongue',
#   782: 'ct scan of the thorax',
#   783: 'the eighth left rib lesion with ongoing centripetal reconstruction',
#   784: 'emergency ct',
#   785: 'two synchronous metastases',
#   786: 'axial mri through the sphenoid sinus on t1 with gadolinium,',
#   787: 'the same clinoidal meningioma',
#   788: 'the proximal luno triquetral joint space indicating a fibro cartilage coalition',
#   789: 'the sacro iliac screw in a deficient bone stock',
#   790: 'Hyperintense well-defined mass at the C2-C3 level of cervical spinal cord with wide dural attachment',
#   791: 'a tumor reduced in size',
#   792: 'bilateral ophthalmic vein thrombosis with cavernous sinus thrombosis',
#   793: 'a large hyperdense structure in the tail of the pancreas with extensive enhanced peripheral areas',
#   794: 'ct of the chest one week after injury',
#   795: 'mri image of brain with gadolinium contrast',
#   796: 'severe joint destruction, obscure subcartilaginous bone plates, central and peripheral erosions, abscesses and articular cartilage damage',
#   797: 'right parietal regions',
#   798: 'in peri gastric veins',
#   799: 'the infarct',
#   800: 'the large polyp in the esophagus nearly occluding the lumen',
#   801: 'external compression of the bladder by the abdominal aortic and internal iliac artery aneurysm',
#   802: 'a rim enhancing and irregular fluid collection',
#   803: 'intense enhancement of the mass',
#   804: 'postoperative sagittal magnetic resonance imaging t2w',
#   805: 'of a loose body in the posterior compartment with a possible osteochondral defect in the dorsal articular surface of capitellum',
#   806: 'narrowing of the oropharynx due to the membrane',
#   807: 'an abnormal dilated branch of the middle cerebral artery in the left hemisphere in a patient with morning glory syndrome associated with persistent hyperplastic primary vitreous',
#   808: 'contrast enhanced t1 mri',
#   809: 'head of pancreas, as well as hepatic and renal cysts',
#   810: 'ct scan of the neck',
#   811: 'axial flair mri image',
#   812: 'basal predominance',
#   813: 'transversal section of the abdominal ct scan',
#   814: 'the posterior lobule',
#   815: 'mri brain coronal section flair image',
#   816: 'mri thoracic spine',
#   817: 'hyper intensities suggestive of venous infarcts',
#   818: 'a well developed epiphyseal tubercle that is clearly displacing out of the metaphyseal socket as an acute on chronic slip develops',
#   819: 'axial ct scans',
#   820: 't2 weighted image of orbital mri',
#   821: 'the lesion in the left masticator space',
#   822: 'basal enhancement of the leptomeninges',
#   823: 'near total tumor removal',
#   824: 'of the frontal bone and expansion of the frontal sinus',
#   825: 'post operative coronal ct',
#   826: 'representative axial ct scan image',
#   827: 'ct of chest',
#   828: 'the presence of persistent cloaca',
#   829: 'the prostatic neoplasm',
#   830: 'bilateral avascular necrosis',
#   831: 'a minimal amount of pneumocephalus and defect in the right sphenoidal sinus',
#   832: 'multifoci of hypointensity and fragmentation of the accessory center',
#   833: 'peritonitis',
#   834: 'an extradural lesion extending from t3 to t11 which became enhanced after a contrast injection',
#   835: 'Conglomerated-ring enhancement',
#   836: 'of a metastatic mass in the bilateral internal auditory canals',
#   837: 'in the fundal region of gallbladder',
#   838: 'the front part of left ventricular band was more hypertrophy than its right counterpart',
#   839: 'lowest level of spinal cord',
#   840: 'of the trachea following prolonged et placement',
#   841: 'in right iliac fossa',
#   842: 'chondral erosions',
#   843: 'the acute hemorrhage in the pineal region extending to the third ventricle',
#   844: 'anomalous concentration',
#   845: 'small bowel in several loops',
#   846: 'a large well defined cystic lesion in sacrococcygeal area',
#   847: 'due to intrarenal vascular thrombosis',
#   848: 'left adrenal adenoma',
#   849: 'post contrast coronal ct image',
#   850: 'proximal jejunal mass',
#   851: 'significant talocalcaneal coalition',
#   852: 'at the afferent loop around hepaticojejunostomy site',
#   853: 'the disc herniation',
#   854: 'of the middle cerebral artery in the left hemisphere in a patient with morning glory syndrome associated with persistent hyperplastic primary vitreous',
#   855: 'the entire cuboid bone replaced with abnormal signal intensity',
#   856: 'a ventral subdural collection at c2-t1',
#   857: 'destruction of left alveolar process and floor of the left maxillary sinus with soft tissue component infiltrating into it',
#   858: 't2 weighted axial magnetic resonance imaging',
#   859: 'mri of case 30',
#   860: 'incisional lumbar hernia',
#   861: 'mri of abdomen',
#   862: 'a large pineal cavernoma',
#   863: 'multiple lymph nodes',
#   864: 'the ethmoidonasal, and intraorbital extension',
#   865: 'in floor of nasal cavity in septum',
#   866: 'a contrast enhanced ct scan',
#   867: 'the adjacent facet',
#   868: 'extensive ground glass opacities',
#   869: 'on the right side',
#   870: 'angle between the line connecting the posterior femoral condyles and the line connecting the medial sulcus and lateral epicondyle measures the femoral condylar twist angle',
#   871: 'in distal pancreas',
#   872: 'at the inferior aspect of the glenoid neck',
#   873: 'erosion of the clinoid process',
#   874: 'post contrast axial ct',
#   875: 'l1 l4 homogenous enhancing lesion',
#   876: 'multiple high density stones in the gallbladder',
#   877: 'ct abdomen with and without contrast',
#   878: 'multiple cerebral infarctions',
#   879: 'the left seminal vesicle cyst',
#   880: 'ruptured artery supplying the interpole',
#   881: 'postoperative axial t2 weighted magnetic resonance imaging',
#   882: 'haemoperitoneum and laceration of the spleen',
#   883: 'type iv optic nerve bilaterally',
#   884: 'large retroperitoneal cyst with no septations',
#   885: 'axial diffusion weighted imaging magnetic resonance imaging',
#   886: 'relapsed lymphoma',
#   887: 'the ascending aorta',
#   888: 'that multiple round hypodense nodules located generally in liver parenchymal and renal cortex',
#   889: 'long segment of intramedullary spinal cord t2 abnormal subtle bright signal consistent myelitis',
#   890: 'an abscess within the deformed pubic ramus and the adductor longus',
#   891: 'without recurrence',
#   892: 'ct scan of cervical spine',
#   893: 'in posterior cortex of left kidney',
#   894: 'subluxation at C5-C6 with disk-space diastasis demonstrating concern for extension-distraction injury',
#   895: 'synovial sarcoma invading pulmonary artery',
#   896: 'symmetric, high intensity signal in the pons with sparing of the peripheral portion',
#   897: 'a balky tumor in lower rectum',
#   898: 'the uncinate process of the pancreas is extended and fused to the dorsal surface of the pancreas body by surrounding the portal vein',
#   899: 'mri of the spinal cord',
#   900: 'area with enhancement in left pars petrosa',
#   901: 'axial mri slice',
#   902: 'the disappearance of the paraspinal tumor',
#   903: 'the t1 weighted magnetic resonance imaging scan of the high density porous polyethylene implant',
#   904: 'adjacent structures along the left psoas muscle',
#   905: 'muscle and subcutaneous oedema',
#   906: 'throughout both lungs',
#   907: 'magnetic resonance imaging scan of the lumbosacral spine',
#   908: 'delta sign demonstrating superior sinus thrombosis',
#   909: 'a irregular, spiculated nodule with cavity',
#   910: 'around the lesion',
#   911: 'the left coronary artery to the ascending aorta',
#   912: 'a csf intensity cystic lesion in right temporoparietal region',
#   913: 'The position of treatment couch removed',
#   914: 'a cerebellar atrophy most pronounced in the vermis',
#   915: 'primary RCC',
#   916: 'Multiple pons infarcts on diffusion-weighted images',
#   917: 'ct image',
#   918: 'a bright object in floor of nasal cavity in septum',
#   919: 'hyperintense signal changes in right internal capsule and basal ganglionic region',
#   920: 'in both sacroiliac joints ',
#   921: 't2 weighted magnetic resonance image',
#   922: 'no enhanced region',
#   923: 'in right kidney',
#   924: 'with craniotomy defect',
#   925: 'both intrahepatic bile ducts',
#   926: 'continuity from the cyst to the maxillary sinus',
#   927: 'a diffuse interstitial pulmonary fibrosis, with subpleural involvement, honeycombing and bronchiectasis, characteristics of a usual pattern of interstitial pneumonia',
#   928: 'in the left parietal lobe',
#   929: 'a filling defect in the right vertebral artery consistent with dissection',
#   930: 'right side lung mass lesion extending into pleura with multiple small nodules on left side',
#   931: 'after erlotinib treatment',
#   932: 'in normal localization',
#   933: 't2 weighted image of mri brain',
#   934: 'two well defined masses with central necrosis',
#   935: 'of increased signal intensity compatible with myocardial fatty substitution',
#   936: 'axial fat suppressed t2 weighted mri',
#   937: 'a soft tissue defect and severe muscular inflammatory infiltration around bone',
#   938: 'contrast enhanced t1 weighted coronal and axial magnetic resonance images of the brain',
#   939: 'axial cut of repeat cervical spine',
#   940: 'axial magnetic resonance imaging',
#   941: 'a superior right orbital mass displacing the globe inferiorly',
#   942: 't2w spair sagittal mri of lower abdomen',
#   943: 'in the upper and middle lobe of the right lung',
#   944: 'poorly differentiated adenocarcinoma',
#   945: 'large mycotic aneurysm',
#   946: 'subchondral cyst in the left tmj',
#   947: 'hrct scans',
#   948: 'on the right lobe of the liver',
#   949: 'a small optic chiasm, a hypoplastic pituitary stalk, an empty sella and a partial hypoplasia of corpus callosum',
#   950: 'the dysplastic of axis body',
#   951: 't2 prolongation in the morel lavallee lesion of the anteromedial right thigh soft tissues',
#   952: 'a 3 cm round hypodense mass at the upper pole of the transplanted kidney',
#   953: 'at the cranio cervical junction',
#   954: 'Tear of the left brachial plexus',
#   955: 'pre operative mri coronal view',
#   956: 'sagittal t2 weighted mri of woman with normal lumbar segmentation',
#   957: 'lesion in the right breast and moderate right axillary lymphadenopathy',
#   958: 'normal imaging without any vascular abnormality',
#   959: 'sagittal cut of repeat cervical spine',
#   960: 'huge heterogeneously enhancing mass with some necrotic foci which has filled the abdominal and pelvic cavities',
#   961: 'the very large arachnoid cyst and extradural hematoma over the left frontoparietal convexity',
#   962: 'presence of intense fdg uptake in the gastric curvatures with thickening',
#   963: 'ct head without contrast',
#   964: 'total left hemisphere encephalomalasia which looked like the previous cranial ct',
#   965: 'of wall of the small intestine',
#   966: 'of the hematoma and decompression of the dural sac and roots',
#   967: 'of posterior aspect of globe',
#   968: 'a large heterogeneous left renal tumor',
#   969: 'a large, well-defined mass lesion in left thalamic region',
#   970: 'sigmoid diverticulitis and free air',
#   971: 'high signal intensity of the mass in the pelvis',
#   972: 'cardiac magnetic resonance image',
#   973: 'edema and breakdown of muscle architecture',
#   974: 'skull fractures and fragmentation with acute intracerebral hemorrhage and midline shift',
#   975: 'the extent of epidural abscess',
#   976: 'air',
#   977: 'an area of low attenuation change in the left temporal lobe',
#   978: 'mild synchondroses of the vertebral bodies',
#   979: 'multiple tubercular granulomas',
#   980: 'in the pancreatic tail',
#   981: 'ct scan of the head in axial cuts',
#   982: 'the small hemorrhagic lesion lateral to the ventricle atrium',
#   983: 'up to the pleural surface',
#   984: 'cortical disruption and adjacent soft tissue swelling at the posterior aspect of the sternum',
#   985: 'cord',
#   986: 'a mass in the right lobe of the liver',
#   987: 'ct with mediastinal window',
#   988: 'size of L1 lesion',
#   989: 'ct scan of the right wrist',
#   990: 'avm in each lower lobe',
#   991: 'polymicrogyria, complete band heterotopia, and colpocephaly',
#   992: 'mild thickening of the distal ileum mucosal folds',
#   993: 'multiple pulmonary arterial aneurysms with left pulmonary infarction',
#   994: 'of infra orbital margin',
#   995: 'in the left lung',
#   996: 'in the right lower lobe',
#   997: 'at the left upper pole',
#   998: 'ct brain with contrast axial film',
#   999: 'presence of an active contrast leak ',
#   ...}}

# %% [markdown]
# ### Creating the model

# %% [markdown]
# #### The functions the gets the model:

# %% [markdown]
# ##### Get Embedding:

# %%
import numpy as np
import random
import h5py
def prepare_embeddings(metadata):
    embedding_filename = embedding_matrix_filename
    num_words = len(metadata['ix_to_word'].keys())
    dim_embedding = embedding_dim



    logger.debug("Embedding Data...")
    # texts = df['question']

    embeddings_index = {}
    i = -1
    line = "NO DATA"


    glove_line_count = File.file_len(glove_path, encoding="utf8")
    def process_line(i, line):
        print_progress(i, glove_line_count)
        try:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
            print_progress(i+1, glove_line_count)
        except Exception as ex:
            logger.error(
                "An error occurred while working on glove file [line {0}]:\n"
                "Line text:\t{1}\nGlove path:\t{2}\n"
                "{3}".format(
                    i, line, glove_path, ex))
            raise


    # with open(glove_path, 'r') as glove_file:
    with VerboseTimer("Embedding"):
        with open(glove_path, 'r', encoding="utf8") as glove_file:
            [process_line(i=i, line=line)for i, line in enumerate(glove_file)]



    embedding_matrix = np.zeros((num_words, dim_embedding))
    word_index = metadata['ix_to_word']

    with VerboseTimer("Creating matrix"):
        embedding_tupl = ((word, i, embeddings_index.get(word)) for word, i in word_index.items())
        embedded_with_values = [(word, i, embedding_vector) for word, i, embedding_vector in embedding_tupl if embedding_vector is not None]

        for word, i, embedding_vector in embedded_with_values:
            embedding_matrix[i] = embedding_vector


    e = {tpl[0] for tpl in embedded_with_values}
    w = set(word_index.keys())
    words_with_no_embedding = w-e
    rnd = random.sample(words_with_no_embedding , 5)
    logger.debug("{0} words did not have embedding. e.g.:\n{1}".format(len(words_with_no_embedding),rnd))

    with VerboseTimer("Dumping matrix"):
        with h5py.File(embedding_filename, 'w') as f:
            f.create_dataset('embedding_matrix', data=embedding_matrix)

    return embedding_matrix

if os.path.exists(embedding_matrix_filename):
    logger.debug("Embedding Data already exists. Loading...")
    with h5py.File(embedding_matrix_filename) as f:
        embedding_train = np.array(f['embedding_matrix'])    
else:
    embedding_train = prepare_embeddings(meta_train)
    
embedding_matrix = embedding_train
embedding_matrix
# Out:
# 21:21:08,87 pythonVQA DEBUG ## Embedding Data already exists. Loading...
# array([[-0.44398999,  0.12817   , -0.25246999, ..., -0.20043001,
#         -0.082191  , -0.06255   ],
#        [ 0.08561   ,  0.077471  , -1.01680005, ..., -0.30044001,
#          0.012508  ,  0.24875   ],
#        [-0.16277   ,  0.033858  , -0.39416999, ...,  0.20255999,
#         -0.17546999, -0.30397999],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.21359   ,  0.85279   ,  0.48688999, ..., -0.19047   ,
#         -0.058526  , -0.49094   ],
#        [ 0.72328001, -0.1178    , -0.022166  , ...,  0.49592999,
#         -0.16937999, -0.58451003]])
